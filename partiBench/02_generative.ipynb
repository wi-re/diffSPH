# %%
# %matplotlib widget
from diffSPH.v2.parameters import parseDefaultParameters, parseModuleParameters
from diffSPH.v2.sampling import sampleParticles
from diffSPH.v2.util import countUniqueEntries, printState
from diffSPH.v2.plotting import updatePlot, visualizeParticles, prepVisualizationState

from diffSPH.v2.modules.integration import integrate
from diffSPH.v2.modules.neighborhood import neighborSearch
from diffSPH.v2.modules.shifting import solveShifting
from diffSPH.v2.modules.timestep import computeTimestep

from diffSPH.v2.simulationSchemes.deltaPlus import simulationStep    
from diffSPH.v2.modules.viscosity import computeViscosityParameter, setViscosityParameters
from tqdm.autonotebook import tqdm
import matplotlib.pyplot as plt
import numpy as np
import torch
import copy
import os
import datetime
from diffSPH.v2.util import computeStatistics
import tomli

# %%
configurationFile = './configurations/01_tgv.toml'

with open(configurationFile, 'r') as f:
    config = f.read()

config = tomli.loads(config)

# %%
# config

# %%
nx = 128
L = 1
u_mag = 2
k = 1 * np.pi
TGV_override = False
targetRe = 2000

config['domain']['minExtent'] = -L
config['domain']['maxExtent'] =  L

config['particle'] = {'nx' : nx}
config['fluid'] = {'cs' : u_mag * 10}
config['compute'] = {'device': 'cuda'}
config['plot']['export'] = True
config['kernel'] = {'name': 'Wendland4'}
# config['kernel']['targetNeighbors'] = 100
# config['compute'] = {'device': 'cpu'}

config = parseDefaultParameters(config)
config = parseModuleParameters(config)
setViscosityParameters(config, targetRe, L, u_mag)
config['integration']['scheme'] = 'symplecticEuler'
config['integration']['scheme'] = 'semiImplicitEuler'

print(rf'Re = {config["diffusion"]["Re"]}, $\nu_{{sph}} = {config["diffusion"]["nu_sph"]}$, $\alpha = {config["diffusion"]["alpha"]}$')
# Out:
# $\alpha = 0.00943240337073803$ is very low, consider increasing the value (should be > 0.01)
# Re = 1999.9996337890625, $\nu_{sph} = 0.0020000003278255463$, $\alpha = 0.00943240337073803$

# %%
# def sampleNoisyParticles(noiseConfig, config, sdfs = [], randomizeParticles = False):
#     particlesA, volumeA = sampleRegular(config['particle']['dx'], config['domain']['dim'], config['domain']['minExtent'], config['domain']['maxExtent'], config['kernel']['targetNeighbors'], config['simulation']['correctArea'], config['kernel']['function'])
#     particlesA = particlesA.to(config['compute']['device'])
#     volumeA = volumeA.to(config['compute']['device'])
    
#     area = (4 / config['particle']['nx']**2)
#     area = volumeA
#     grid, noiseSimplex = sampleNoise(noiseConfig)

#     noiseState = {}
#     noiseState['numParticles'] = particlesA.shape[0]
#     # noiseState['timestep'] = 0
#     # noiseState['time'] = 0.
#     # noiseState['dt'] = config['timestep']['dt']
#     noiseState['positions'] = particlesA
#     noiseState['areas'] = particlesA.new_ones(particlesA.shape[0]) * area
#     noiseState['pressures'] = particlesA.new_zeros(particlesA.shape[0])
#     noiseState['divergence'] = particlesA.new_zeros(particlesA.shape[0])
#     noiseState['masses'] = noiseState['areas'] * config['fluid']['rho0']
#     noiseState['supports'] = volumeToSupport(area, config['kernel']['targetNeighbors'], config['domain']['dim']) * particlesA.new_ones(particlesA.shape[0])
#     noiseState['index'] = torch.arange(particlesA.shape[0], device = particlesA.device)
#     noiseState['densities'] = particlesA.new_ones(particlesA.shape[0]) * config['fluid']['rho0'] 
#     noiseState['velocities'] = particlesA.new_zeros(particlesA.shape[0], config['domain']['dim'])
#     noiseState['accelerations'] = particlesA.new_zeros(particlesA.shape[0], config['domain']['dim'])
#     if len(sdfs) > 0:
#         noiseState['distances'] = particlesA.new_ones(particlesA.shape[0]) * np.inf

#     if randomizeParticles:
#         baseShiftingConfig = copy.deepcopy(config['shifting'])

#         config['shifting']['solver'] = 'BiCGStab_wJacobi'
#         # config['shifting']['solver'] = 'BiCGStab'
#         config['shifting']['maxIterations'] = 64
#         config['shifting']['freeSurface'] = False
#         config['shifting']['summationDensity'] = False
#         config['shifting']['scheme'] = 'IPS'
#         config['shifting']['maxSolveIter'] = 128
#         config['shifting']['initialization'] = 'zero'
#         config['shifting']['threshold'] = 0.5

#         positions = torch.rand(noiseState['positions'].shape, device = noiseState['positions'].device) * 2 - 1
#         shiftState = {
#                 'positions': positions,
#                 'areas': noiseState['areas'],
#                 'densities': noiseState['densities'],\
#                 'numParticles': noiseState['numParticles'],
#                 'velocities': noiseState['velocities'],
#                 'masses': noiseState['masses'],
#                 'supports': noiseState['supports'],
#             }
#         dx, states = solveShifting({
#             'fluid':shiftState
#         }, config)
#         shiftState['positions'] = positions + dx

#         config['shifting'] = baseShiftingConfig

#         x = shiftState['positions'].clone()

#         periodic = config['domain']['periodicity']
#         minDomain = config['domain']['minExtent']
#         maxDomain = config['domain']['maxExtent']
#         periodicity = torch.tensor([False] * x.shape[1], dtype = torch.bool).to(x.device)
#         if isinstance(periodic, torch.Tensor):
#             periodicity = periodic
#         if isinstance(periodic, bool):
#             periodicity = torch.tensor([periodic] * x.shape[1], dtype = torch.bool).to(x.device)

#         mod_positions = torch.stack([x[:,i] if not periodic_i else torch.remainder(x[:,i] - minDomain[i], maxDomain[i] - minDomain[i]) + minDomain[i] for i, periodic_i in enumerate(periodicity)], dim = 1)
#         lin_x = (mod_positions[:,0] - minDomain[0]) / (maxDomain[0] - minDomain[0])
#         lin_y = (mod_positions[:,1] - minDomain[1]) / (maxDomain[1] - minDomain[1])

#         gridDim = 128 // 2
#         linearIndex = (torch.round(lin_x * gridDim) + torch.round(lin_y * gridDim) * gridDim).to(torch.int32)
#         sortedIndices = torch.argsort(linearIndex)
#         sortedPositions = mod_positions[sortedIndices]
#         shiftState['positions'] = sortedPositions

#         _, noiseNeighbors = neighborSearch(shiftState, noiseState, config)

#         noise = noiseSimplex.flatten().to(particlesA.device)
#         noiseState['potential'] = sphOperationStates(noiseState, shiftState, (noise, noise), operation = 'interpolate', neighborhood = noiseNeighbors)
#         noiseState['positions'] = shiftState['positions']



#     else:
#         noiseState['potential'] = noiseSimplex.flatten().to(particlesA.device)




#     # mask = torch.ones_like(noiseState['areas'], dtype = torch.bool)
#     # fluid_sdfs = [sdf['sdf'] for sdf in sdfs if sdf['type'] == 'fluid' ]   
#     # mask = None
#     # if len(fluid_sdfs) > 0:
#     #     mask = torch.zeros_like(noiseState['areas'], dtype = torch.bool)

#     #     for sdf_func in fluid_sdfs:
#     #         _, maskA, sdfValues, _ = filterParticlesWithSDF(particlesA, sdf_func, noiseState['supports'][0], -1e-4)
#     #         mask = mask | maskA
#     #         noiseState['distances'] = torch.min(noiseState['distances'], sdfValues)
#     #     mask = mask.to(config['compute']['device'])
#     # noiseState['velocities'][~mask, :] = 0

#     samplings = None
#     if samplings is None:   
#         samplings = ['regular' for _ in sdfs]
#     if not isinstance(samplings, List):
#         samplings = [samplings for _ in sdfs]

#     boundary_sdfs = [sdf['sdf'] for sdf in sdfs if sdf['type'] == 'boundary' ]   
    
#     boundaryParticles, boundaryVolumes, boundaryDistances, boundaryNormals, boundaryBodyIDs, fluidMask = sampleBoundaryParticles(noiseState, boundary_sdfs, config, samplings)
#     for k in noiseState.keys():
#         if isinstance(noiseState[k], torch.Tensor):
#             noiseState[k] = noiseState[k][fluidMask]
#     noiseState['numParticles'] = noiseState['positions'].shape[0]
            
#     _, fluidNeighborhood = neighborSearch(noiseState, noiseState, config)

#     noiseState['neighborhood'] = fluidNeighborhood
#     # printState(noiseState)
    
#     # printState(noiseState)

#     # for sdf in boundary_sdfs:
#     #     # _, maskA, _, _ = filterParticlesWithSDF(particlesA, operatorDict['invert'](sdf), config['particle']['support'], -1e-4)
#         # noiseState['potential'] = filterPotentialField(operatorDict['invert'](sdf), noiseState, config, kind = 'divergenceFree')
#         # noiseState['potential'] = filterPotentialField(sdf, noiseState, config, kind = 'divergenceFree')


#     noiseState['velocities'], noiseState['divergence'] = sampleVelocityField(noiseState, noiseState['neighborhood'])
#     # if mask is None:
#         # mask = torch.ones_like(noiseState['potential'], dtype = torch.bool)
#     # for sdf_func in boundary_sdfs:
#         # _, maskA, _, _ = filterParticlesWithSDF(particlesA, operatorDict['invert'](sdf), config['particle']['support'], -1e-4)
#         # _, maskA, _, _ = filterParticlesWithSDF(particlesA, sdf, config['particle']['support'], -1e-4)
#         # mask = mask & maskA
#     # noiseState['velocities'][~mask, :] = 0

#     _, noiseState['numNeighbors'] = countUniqueEntries(fluidNeighborhood['indices'][0], noiseState['positions'])

#     return noiseState, None

# %%
from torch.profiler import profile, record_function, ProfilerActivity
from diffSPH.v2.modules.inletOutlet import processInlet, processOutlet, processForcing
from diffSPH.v2.plotting import plotRegions
from diffSPH.v2.sdf import getSDF, sdfFunctions, operatorDict
from diffSPH.v2.sampling import find_contour

ngrid = 255
x = torch.linspace(config['domain']['minExtent'][0], config['domain']['maxExtent'][0], ngrid, dtype = torch.float32)
y = torch.linspace(config['domain']['minExtent'][1], config['domain']['maxExtent'][1], ngrid, dtype = torch.float32)
X, Y = torch.meshgrid(x, y, indexing = 'ij')
P = torch.stack([X,Y], dim=-1)
points = P.reshape(-1,2)


sphere_b = lambda points: getSDF('box')['function'](points, torch.tensor([1/8,1/2]).to(points.device))
inletSDF = operatorDict['translate'](sphere_b, torch.tensor([-2 + 1/8,0.]))
# fx = sdf(torch.clone(points)).to('cpu').reshape(ngrid,ngrid)


sphere_b = lambda points: getSDF('box')['function'](points, torch.tensor([1/8,1]).to(points.device))
outletSDF = operatorDict['translate'](sphere_b, torch.tensor([2 - 1/8,0.]))
# fx = sdf(torch.clone(points)).to('cpu').reshape(ngrid,ngrid)

sphere_b = lambda points: getSDF('box')['function'](points, torch.tensor([1/4,1.5]).to(points.device))
outletRegion = operatorDict['translate'](sphere_b, torch.tensor([2 - 1/4,0.]))
# fx = sdf(torch.clone(points)).to('cpu').reshape(ngrid,ngrid)

inner = lambda points: getSDF('box')['function'](points, torch.tensor([1,1]).to(points.device))
outer = lambda points: getSDF('box')['function'](points, torch.tensor([1 + config['particle']['dx'] * boundary_width,1 + config['particle']['dx'] * boundary_width]).to(points.device))
outer = operatorDict['invert'](outer)
sdf = operatorDict['union'](inner, outer)
boundary_sdf = operatorDict['invert'](inner)


fluid_sdf = lambda points: getSDF('box')['function'](points, torch.tensor([1,1]).to(points.device))
# fluid_sdf = operatorDict['translate'](sphere_b, torch.tensor([-2 + 1/2, - 1/2]))


regions = [
    # {
    #     'sdf': inletSDF,
    #     'type': 'inlet',
    #     'velocity': torch.tensor([1,0.]),
    #     'particles': sampleParticles(config, sdfs = [inletSDF])[0],
    #     'contour': find_contour(inletSDF(points).reshape(ngrid, ngrid).cpu(), config['domain']['minExtent'].cpu(), config['domain']['maxExtent'].cpu(), ngrid, 0)
    # },
    # {
    #     'sdf': inletSDF,
    #     'type': 'forcing',
    #     'forcingMode': 'immediate',
    #     'velocity': torch.tensor([1,0.]),
    #     'particles': sampleParticles(config, sdfs = [inletSDF])[0],
    #     'contour': find_contour(inletSDF(points).reshape(ngrid, ngrid).cpu(), config['domain']['minExtent'].cpu(), config['domain']['maxExtent'].cpu(), ngrid, 0)
    # },{
    #     'sdf': outletSDF,
    #     'type': 'outlet',
    #     'velocity': torch.tensor([0.,0.]),
    #     'particles': sampleParticles(config, sdfs = [outletSDF])[0],
    #     'contour': find_contour(outletSDF(points).reshape(ngrid, ngrid).cpu(), config['domain']['minExtent'].cpu(), config['domain']['maxExtent'].cpu(), ngrid, 0)
    # },{
    #     'sdf': outletRegion,
    #     'type': 'mirror',
    #     'velocity': torch.tensor([0.,0.]),
    #     'particles': sampleParticles(config, sdfs = [outletRegion])[0],
    #     'contour': find_contour(outletRegion(points).reshape(ngrid, ngrid).cpu(), config['domain']['minExtent'].cpu(), config['domain']['maxExtent'].cpu(), ngrid, 0)
    # },
{
        'sdf': fluid_sdf,
        'type': 'fluid',
        'velocity': torch.tensor([0.,0.]),
        # 'particles': sampleParticles(config, sdfs = [fluid_sdf])[0],
        'contour': find_contour(fluid_sdf(points).reshape(ngrid, ngrid).cpu(), config['domain']['minExtent'].cpu(), config['domain']['maxExtent'].cpu(), ngrid, 0)
    }
    ]

config['regions'] = regions

# fig, axis = plt.subplots(1,2, figsize = (15,5), squeeze = False)
# setPlotBaseAttributes(axis[0,0], config)
# # setPlotBaseAttributes(axis[0,1], config)

# # plotRegions(regions, axis[0,0])
# plotRegions(regions, axis[0,0])

# %%
from diffSPH.v2.sampling import sampleNoisyParticles
from diffSPH.v2.modules.divergence import computeDivergence
from diffSPH.v2.plotting import plotSDF
from diffSPH.v2.sdf import getSDF, operatorDict

# particleState, mask = sampleParticles(config, sdfs = [])
particleState, mask = sampleNoisyParticles(config['noise'], config, sdfs = regions, randomizeParticles = False)

priorState = None
# particleState['velocities'][:,0] =  u_mag * torch.cos(k * particleState['positions'][:,0]) * torch.sin(k * particleState['positions'][:,1])
# particleState['velocities'][:,1] = -u_mag * torch.sin(k * particleState['positions'][:,0]) * torch.cos(k * particleState['positions'][:,1])

# u_max = torch.linalg.norm(particleState['velocities'], dim = 1).max()
# particleState['velocities'] = particleState['velocities'] / (u_max + 1e-7) * u_mag
Ek0 = 0.5 * particleState['areas'] * particleState['densities'] * torch.linalg.norm(particleState['velocities'], dim = -1)**2

initialVelocities = particleState['velocities'].clone()

particleState['Eks'] =  (0.5 * particleState['areas'] * particleState['densities'] * torch.linalg.norm(initialVelocities, dim = -1)**2)
particleState['E_k'] = particleState['Eks'].sum().cpu().detach().item()

# %%
# from diffSPH.v2.simulationSchemes.deltaPlus import simulationStep
from diffSPH.v2.simulationSchemes.dfsph import simulationStep
from diffSPH.v2.modules.momentumEquation import computeMomentumEquation
from diffSPH.v2.modules.neighborhood import searchNeighbors

from diffSPH.v2.sampling import generateInitialConditions
from diffSPH.v2.simulationSchemes.dfsph import callModule, computeDensity, computeViscosity, dfsphSolve, computeGravity
initialState = {
    
    'fluid': particleState,
    'time': 0.0,
    'timestep': 0,
    'dt': torch.tensor(5e-4, device = config['compute']['device']),
}


# initialState = generateInitialConditions(particleState, config)


initialState['fluid']['positions'] += torch.normal(0, 1e-2, initialState['fluid']['positions'].shape).to(initialState['fluid']['positions'].device)

state = copy.deepcopy(initialState)

config['dfsph']['maxIters'] = 256
config['dfsph']['errorThreshold'] = 1e-5/ config['fluid']['rho0']
config['dfsph']['omega'] = 1/33
config['dfsph']['sourceTerm'] = 'density'
config['dfsph']['clampPressure'] = False
# if verbose:
    # print('DFSPH steps')
i = 0
while(True):
    i += 1
    searchNeighbors(state, config)

    state['fluid']['densities'], _ = callModule(state, computeDensity, config, 'fluid')
    # print(f'Iteration {i}, rho = {state["fluid"]["densities"].mean()}')
    state['fluid']['velocityDiffusion'], _ = callModule(state, computeViscosity, config, 'fluid')
    state['fluid']['gravityAccel'] = computeGravity(state['fluid'], config)
    state['fluid']['gravityAccel'] = state['fluid']['gravityAccel'] * 0
    state['fluid']['advection'] = state['fluid']['gravityAccel'] + state['fluid']['velocityDiffusion']
    state['fluid']['pressureAccel'], _ = callModule(state, dfsphSolve, config, 'fluid')
    state['fluid']['pressureIncompressible'] = state['fluid']['pressureB']
    dudt = state['fluid']['pressureAccel'] + state['fluid']['gravityAccel'] + state['fluid']['velocityDiffusion']

    state['fluid']['accelerations'] = dudt
    state['fluid']['velocities'] = state['fluid']['velocities'] + state['fluid']['accelerations'] * state['dt']
    state['fluid']['positions'] = state['fluid']['positions'] + state['fluid']['velocities'] * state['dt']
    state['fluid']['velocities'] = state['fluid']['velocities'] * 0.
    # if verbose:
    print(f'Iteration {i}, rho = {state["fluid"]["densities"].mean()} Iterations: {len(state["fluid"]["convergence_density"])}, residual: {state["fluid"]["convergence_density"][-1]}')
    if state["fluid"]["convergence_density"][-1] < 1e-4 / config['fluid']['rho0'] or i > 256:
        break

del state['fluid']['pressureIncompressible']

state['fluid']['velocities'][:,0] =  u_mag * torch.cos(k * state['fluid']['positions'][:,0]) * torch.sin(k * state['fluid']['positions'][:,1])
state['fluid']['velocities'][:,1] = -u_mag * torch.sin(k * state['fluid']['positions'][:,0]) * torch.cos(k * state['fluid']['positions'][:,1])
state['fluid']['Eks'] =  (0.5 * state['fluid']['areas'] * state['fluid']['densities'] * torch.linalg.norm(state['fluid']['velocities'], dim = -1)**2)
state['fluid']['E_k'] = state['fluid']['Eks'].sum().cpu().detach().item()


perennialState = copy.deepcopy(state)
config['dfsph']['maxIters'] = 512
config['dfsph']['errorThreshold'] = 5e-4
config['dfsph']['omega'] = 0.33

config['timestep']['dt'] = 5e-4
perennialState['dt'] = 5e-4
perennialState['fluid']['densities'][:] = config['fluid']['rho0']

priorState = None
perennialState, priorState, *updates = integrate(simulationStep, perennialState, config, previousStep= priorState)
perennialState['time'] += perennialState['dt']

searchNeighbors(perennialState, config)
div = computeMomentumEquation(perennialState['fluid'], perennialState['fluid'], perennialState['fluid']['neighborhood'], config)
# Out:
# Iteration 1, rho = 1115.8223876953125 Iterations: 256, residual: 3.818028744717594e-06
# Iteration 2, rho = 1031.11962890625 Iterations: 256, residual: 3.8675652831443585e-06
# Iteration 3, rho = 1012.705810546875 Iterations: 256, residual: 4.321338565205224e-06
# Iteration 4, rho = 1006.8665771484375 Iterations: 256, residual: 4.043592980451649e-06
# Iteration 5, rho = 1004.6947021484375 Iterations: 256, residual: 3.469303010206204e-06
# Iteration 6, rho = 1003.625244140625 Iterations: 256, residual: 2.944533662230242e-06
# Iteration 7, rho = 1002.9879760742188 Iterations: 256, residual: 2.5458830350544304e-06
# Iteration 8, rho = 1002.5595703125 Iterations: 256, residual: 2.2532642560690874e-06
# Iteration 9, rho = 1002.256103515625 Iterations: 256, residual: 2.033311375271296e-06
# Iteration 10, rho = 1002.0319213867188 Iterations: 256, residual: 1.863524857981247e-06
# Iteration 11, rho = 1001.8607177734375 Iterations: 256, residual: 1.728627012198558e-06
# Iteration 12, rho = 1001.7258911132812 Iterations: 256, residual: 1.6192793736991007e-06
# Iteration 13, rho = 1001.6167602539062 Iterations: 256, residual: 1.528665507066762e-06
# Iteration 14, rho = 1001.5264892578125 Iterations: 256, residual: 1.4523307072522584e-06
# Iteration 15, rho = 1001.450439453125 Iterations: 256, residual: 1.387101747241104e-06
# Iteration 16, rho = 1001.3854370117188 Iterations: 256, residual: 1.3306269011081895e-06
# Iteration 17, rho = 1001.3290405273438 Iterations: 256, residual: 1.281119011764531e-06
# Iteration 18, rho = 1001.2796630859375 Iterations: 256, residual: 1.2372556739137508e-06
# Iteration 19, rho = 1001.2359619140625 Iterations: 256, residual: 1.1980496310570743e-06
# Iteration 20, rho = 1001.1969604492188 Iterations: 256, residual: 1.1627510048128897e-06
# Iteration 21, rho = 1001.1617431640625 Iterations: 256, residual: 1.1307420209050179e-06
# Iteration 22, rho = 1001.1298828125 Iterations: 256, residual: 1.1015320069418522e-06
# Iteration 23, rho = 1001.100830078125 Iterations: 256, residual: 1.0747477290351526e-06
# Iteration 24, rho = 1001.0740966796875 Iterations: 256, residual: 1.0500657481316011e-06
# Iteration 25, rho = 1001.049560546875 Iterations: 256, residual: 1.0272212875861442e-06
# Iteration 26, rho = 1001.0267333984375 Iterations: 256, residual: 1.0059893611469306e-06
# Iteration 27, rho = 1001.0055541992188 Iterations: 256, residual: 9.861840908342856e-07
# Iteration 28, rho = 1000.98583984375 Iterations: 256, residual: 9.676484751253156e-07
# Iteration 29, rho = 1000.9673461914062 Iterations: 256, residual: 9.502516036263842e-07
# Iteration 30, rho = 1000.9500122070312 Iterations: 256, residual: 9.33889850784908e-07
# Iteration 31, rho = 1000.93359375 Iterations: 256, residual: 9.184518034999201e-07
# Iteration 32, rho = 1000.918212890625 Iterations: 256, residual: 9.038608368427958e-07
# Iteration 33, rho = 1000.9036865234375 Iterations: 256, residual: 8.900402690414921e-07
# Iteration 34, rho = 1000.889892578125 Iterations: 256, residual: 8.769270607444923e-07
# Iteration 35, rho = 1000.8767700195312 Iterations: 256, residual: 8.644623790132755e-07
# Iteration 36, rho = 1000.8642578125 Iterations: 256, residual: 8.52594212119584e-07
# Iteration 37, rho = 1000.8524169921875 Iterations: 256, residual: 8.412837928517547e-07
# Iteration 38, rho = 1000.8411865234375 Iterations: 256, residual: 8.3047910948153e-07
# Iteration 39, rho = 1000.8303833007812 Iterations: 256, residual: 8.20151967673155e-07
# Iteration 40, rho = 1000.8200073242188 Iterations: 256, residual: 8.102671245069359e-07
# Iteration 41, rho = 1000.8101806640625 Iterations: 256, residual: 8.007984888536157e-07
# Iteration 42, rho = 1000.8007202148438 Iterations: 256, residual: 7.917150242064963e-07
# Iteration 43, rho = 1000.7916259765625 Iterations: 256, residual: 7.829939363546146e-07
# Iteration 44, rho = 1000.7828979492188 Iterations: 256, residual: 7.746144206066674e-07
# Iteration 45, rho = 1000.7745361328125 Iterations: 256, residual: 7.66558457598876e-07
# Iteration 46, rho = 1000.7664794921875 Iterations: 256, residual: 7.58801661504549e-07
# Iteration 47, rho = 1000.7587890625 Iterations: 256, residual: 7.513290256611072e-07
# Iteration 48, rho = 1000.7512817382812 Iterations: 256, residual: 7.441199727509229e-07
# Iteration 49, rho = 1000.7440795898438 Iterations: 256, residual: 7.37169273179461e-07
# Iteration 50, rho = 1000.7371215820312 Iterations: 256, residual: 7.304547580133658e-07
# Iteration 51, rho = 1000.7304077148438 Iterations: 256, residual: 7.239668775582686e-07
# Iteration 52, rho = 1000.723876953125 Iterations: 256, residual: 7.176921030804806e-07
# Iteration 53, rho = 1000.7176513671875 Iterations: 256, residual: 7.116253755157231e-07
# Iteration 54, rho = 1000.7116088867188 Iterations: 256, residual: 7.057501534291077e-07
# Iteration 55, rho = 1000.7056884765625 Iterations: 256, residual: 7.000621735642198e-07
# Iteration 56, rho = 1000.7000122070312 Iterations: 256, residual: 6.945463155716425e-07
# Iteration 57, rho = 1000.6945190429688 Iterations: 256, residual: 6.892031478855642e-07
# Iteration 58, rho = 1000.689208984375 Iterations: 256, residual: 6.840111268502369e-07
# Iteration 59, rho = 1000.6839599609375 Iterations: 256, residual: 6.789781537008821e-07
# Iteration 60, rho = 1000.678955078125 Iterations: 256, residual: 6.740913249814184e-07
# Iteration 61, rho = 1000.674072265625 Iterations: 256, residual: 6.693373393318325e-07
# Iteration 62, rho = 1000.6693115234375 Iterations: 256, residual: 6.647206305387954e-07
# Iteration 63, rho = 1000.6647338867188 Iterations: 256, residual: 6.602300572922104e-07
# Iteration 64, rho = 1000.6602172851562 Iterations: 256, residual: 6.558602763107046e-07
# Iteration 65, rho = 1000.6558227539062 Iterations: 256, residual: 6.516091843877803e-07
# Iteration 66, rho = 1000.651611328125 Iterations: 256, residual: 6.474658107435971e-07
# Iteration 67, rho = 1000.6474609375 Iterations: 256, residual: 6.43431462776789e-07
# Iteration 68, rho = 1000.6434326171875 Iterations: 256, residual: 6.395007403625641e-07
# Iteration 69, rho = 1000.6394653320312 Iterations: 256, residual: 6.35672222415451e-07
# Iteration 70, rho = 1000.6356811523438 Iterations: 256, residual: 6.319353360595414e-07
# Iteration 71, rho = 1000.6319580078125 Iterations: 256, residual: 6.282901381382544e-07
# Iteration 72, rho = 1000.6282958984375 Iterations: 256, residual: 6.247327632991073e-07
# Iteration 73, rho = 1000.624755859375 Iterations: 256, residual: 6.212584366949159e-07
# Iteration 74, rho = 1000.6212768554688 Iterations: 256, residual: 6.178693752190156e-07
# Iteration 75, rho = 1000.6178588867188 Iterations: 256, residual: 6.14557677636185e-07
# Iteration 76, rho = 1000.614501953125 Iterations: 256, residual: 6.113246513450576e-07
# Iteration 77, rho = 1000.611328125 Iterations: 256, residual: 6.08159552939469e-07
# Iteration 78, rho = 1000.608154296875 Iterations: 256, residual: 6.050689762560069e-07
# Iteration 79, rho = 1000.6051025390625 Iterations: 256, residual: 6.020434852871404e-07
# Iteration 80, rho = 1000.60205078125 Iterations: 256, residual: 5.990826821289374e-07
# Iteration 81, rho = 1000.59912109375 Iterations: 256, residual: 5.961900342299487e-07
# Iteration 82, rho = 1000.59619140625 Iterations: 256, residual: 5.93356560329994e-07
# Iteration 83, rho = 1000.5933227539062 Iterations: 256, residual: 5.905810098738584e-07
# Iteration 84, rho = 1000.590576171875 Iterations: 256, residual: 5.878656565982965e-07
# Iteration 85, rho = 1000.587890625 Iterations: 256, residual: 5.852026561115053e-07
# Iteration 86, rho = 1000.585205078125 Iterations: 256, residual: 5.825965558869939e-07
# Iteration 87, rho = 1000.5825805664062 Iterations: 256, residual: 5.800407052447554e-07
# Iteration 88, rho = 1000.5800170898438 Iterations: 256, residual: 5.775341378466692e-07
# Iteration 89, rho = 1000.5775146484375 Iterations: 256, residual: 5.75076569475641e-07
# Iteration 90, rho = 1000.5750732421875 Iterations: 256, residual: 5.726668632632936e-07
# Iteration 91, rho = 1000.5726928710938 Iterations: 256, residual: 5.703059287043288e-07
# Iteration 92, rho = 1000.5703125 Iterations: 256, residual: 5.679859214069438e-07
# Iteration 93, rho = 1000.5679931640625 Iterations: 256, residual: 5.657101951328514e-07
# Iteration 94, rho = 1000.565673828125 Iterations: 256, residual: 5.634739181914483e-07
# Iteration 95, rho = 1000.5634765625 Iterations: 256, residual: 5.612824907075264e-07
# Iteration 96, rho = 1000.561279296875 Iterations: 256, residual: 5.591265335169737e-07
# Iteration 97, rho = 1000.55908203125 Iterations: 256, residual: 5.570113899011631e-07
# Iteration 98, rho = 1000.5570068359375 Iterations: 256, residual: 5.549334787247062e-07
# Iteration 99, rho = 1000.554931640625 Iterations: 256, residual: 5.528914925889694e-07
# Iteration 100, rho = 1000.5528564453125 Iterations: 256, residual: 5.508849767466018e-07
# Iteration 101, rho = 1000.5509033203125 Iterations: 256, residual: 5.489152954396559e-07
# Iteration 102, rho = 1000.5489501953125 Iterations: 256, residual: 5.469756274578685e-07
# Iteration 103, rho = 1000.5469970703125 Iterations: 256, residual: 5.45068701285345e-07
# Iteration 104, rho = 1000.5450439453125 Iterations: 256, residual: 5.431925274024252e-07
# Iteration 105, rho = 1000.543212890625 Iterations: 256, residual: 5.413514827523613e-07
# Iteration 106, rho = 1000.5413818359375 Iterations: 256, residual: 5.395357902671094e-07
# Iteration 107, rho = 1000.53955078125 Iterations: 256, residual: 5.37748860551801e-07
# Iteration 108, rho = 1000.5377197265625 Iterations: 256, residual: 5.359937063076359e-07
# Iteration 109, rho = 1000.5360107421875 Iterations: 256, residual: 5.342675422070897e-07
# Iteration 110, rho = 1000.5343017578125 Iterations: 256, residual: 5.325656502463971e-07
# Iteration 111, rho = 1000.5325927734375 Iterations: 256, residual: 5.308893378241919e-07
# Iteration 112, rho = 1000.5308837890625 Iterations: 256, residual: 5.292433797876583e-07
# Iteration 113, rho = 1000.5292358398438 Iterations: 256, residual: 5.276164074530243e-07
# Iteration 114, rho = 1000.5276489257812 Iterations: 256, residual: 5.260156967779039e-07
# Iteration 115, rho = 1000.5260009765625 Iterations: 256, residual: 5.244432941253763e-07
# Iteration 116, rho = 1000.5244140625 Iterations: 256, residual: 5.228870918472239e-07
# Iteration 117, rho = 1000.52294921875 Iterations: 256, residual: 5.213611871113244e-07
# Iteration 118, rho = 1000.5213623046875 Iterations: 256, residual: 5.198533585826226e-07
# Iteration 119, rho = 1000.5198974609375 Iterations: 256, residual: 5.183697453503555e-07
# Iteration 120, rho = 1000.5183715820312 Iterations: 256, residual: 5.169061410015274e-07
# Iteration 121, rho = 1000.5169067382812 Iterations: 256, residual: 5.154613518243423e-07
# Iteration 122, rho = 1000.5154418945312 Iterations: 256, residual: 5.140381063029054e-07
# Iteration 123, rho = 1000.5140380859375 Iterations: 256, residual: 5.126344149175566e-07
# Iteration 124, rho = 1000.5126342773438 Iterations: 256, residual: 5.112491407999187e-07
# Iteration 125, rho = 1000.51123046875 Iterations: 256, residual: 5.098858082419611e-07
# Iteration 126, rho = 1000.5098876953125 Iterations: 256, residual: 5.085395287096617e-07
# Iteration 127, rho = 1000.508544921875 Iterations: 256, residual: 5.072121211924241e-07
# Iteration 128, rho = 1000.5072021484375 Iterations: 256, residual: 5.059041541244369e-07
# Iteration 129, rho = 1000.5059204101562 Iterations: 256, residual: 5.04607896800735e-07
# Iteration 130, rho = 1000.504638671875 Iterations: 256, residual: 5.033321031078231e-07
# Iteration 131, rho = 1000.5033569335938 Iterations: 256, residual: 5.020744993089465e-07
# Iteration 132, rho = 1000.5020751953125 Iterations: 256, residual: 5.008319021726493e-07
# Iteration 133, rho = 1000.5008544921875 Iterations: 256, residual: 4.996040843252558e-07
# Iteration 134, rho = 1000.4996337890625 Iterations: 256, residual: 4.983937742508715e-07
# Iteration 135, rho = 1000.4984130859375 Iterations: 256, residual: 4.971951739207725e-07
# Iteration 136, rho = 1000.4971923828125 Iterations: 256, residual: 4.960149908583844e-07
# Iteration 137, rho = 1000.4960327148438 Iterations: 256, residual: 4.948478817823343e-07
# Iteration 138, rho = 1000.494873046875 Iterations: 256, residual: 4.936958930557012e-07
# Iteration 139, rho = 1000.4937133789062 Iterations: 256, residual: 4.925576035930135e-07
# Iteration 140, rho = 1000.4925537109375 Iterations: 256, residual: 4.914348892270937e-07
# Iteration 141, rho = 1000.491455078125 Iterations: 256, residual: 4.903226908936631e-07
# Iteration 142, rho = 1000.4903564453125 Iterations: 256, residual: 4.892241349807591e-07
# Iteration 143, rho = 1000.4891967773438 Iterations: 256, residual: 4.88135867726669e-07
# Iteration 144, rho = 1000.4881591796875 Iterations: 256, residual: 4.870681777902064e-07
# Iteration 145, rho = 1000.487060546875 Iterations: 256, residual: 4.860108901993954e-07
# Iteration 146, rho = 1000.4859619140625 Iterations: 256, residual: 4.849616743740626e-07
# Iteration 147, rho = 1000.4849853515625 Iterations: 256, residual: 4.839258167521621e-07
# Iteration 148, rho = 1000.48388671875 Iterations: 256, residual: 4.829015551877092e-07
# Iteration 149, rho = 1000.48291015625 Iterations: 256, residual: 4.818904244530131e-07
# Iteration 150, rho = 1000.4818725585938 Iterations: 256, residual: 4.808885591955914e-07
# Iteration 151, rho = 1000.4808349609375 Iterations: 256, residual: 4.798999384547642e-07
# Iteration 152, rho = 1000.4798583984375 Iterations: 256, residual: 4.789204695043736e-07
# Iteration 153, rho = 1000.47900390625 Iterations: 256, residual: 4.779515734298911e-07
# Iteration 154, rho = 1000.4779663085938 Iterations: 256, residual: 4.769940460391808e-07
# Iteration 155, rho = 1000.47705078125 Iterations: 256, residual: 4.760464094033523e-07
# Iteration 156, rho = 1000.47607421875 Iterations: 256, residual: 4.7510997092103935e-07
# Iteration 157, rho = 1000.47509765625 Iterations: 256, residual: 4.7418450321856653e-07
# Iteration 158, rho = 1000.4741821289062 Iterations: 256, residual: 4.7326699359473423e-07
# Iteration 159, rho = 1000.4732666015625 Iterations: 256, residual: 4.7235857891791966e-07
# Iteration 160, rho = 1000.472412109375 Iterations: 256, residual: 4.7146070869530377e-07
# Iteration 161, rho = 1000.471435546875 Iterations: 256, residual: 4.7056994390004547e-07
# Iteration 162, rho = 1000.4705810546875 Iterations: 256, residual: 4.696934183812118e-07
# Iteration 163, rho = 1000.4697265625 Iterations: 256, residual: 4.6882212245691335e-07
# Iteration 164, rho = 1000.4688110351562 Iterations: 256, residual: 4.6796162678219844e-07
# Iteration 165, rho = 1000.468017578125 Iterations: 256, residual: 4.6710619017176214e-07
# Iteration 166, rho = 1000.4671020507812 Iterations: 256, residual: 4.6626442440356186e-07
# Iteration 167, rho = 1000.46630859375 Iterations: 256, residual: 4.654265239878441e-07
# Iteration 168, rho = 1000.4654541015625 Iterations: 256, residual: 4.646015554499172e-07
# Iteration 169, rho = 1000.464599609375 Iterations: 256, residual: 4.6378082174669544e-07
# Iteration 170, rho = 1000.4637451171875 Iterations: 256, residual: 4.629685577128839e-07
# Iteration 171, rho = 1000.4629516601562 Iterations: 256, residual: 4.6216672444643336e-07
# Iteration 172, rho = 1000.462158203125 Iterations: 256, residual: 4.6137120079947636e-07
# Iteration 173, rho = 1000.46142578125 Iterations: 256, residual: 4.605819015068846e-07
# Iteration 174, rho = 1000.4605712890625 Iterations: 256, residual: 4.598031182467821e-07
# Iteration 175, rho = 1000.4597778320312 Iterations: 256, residual: 4.5902754663984524e-07
# Iteration 176, rho = 1000.458984375 Iterations: 256, residual: 4.582635142469371e-07
# Iteration 177, rho = 1000.458251953125 Iterations: 256, residual: 4.575044272314699e-07
# Iteration 178, rho = 1000.45751953125 Iterations: 256, residual: 4.567542646327638e-07
# Iteration 179, rho = 1000.4567260742188 Iterations: 256, residual: 4.5600847897731e-07
# Iteration 180, rho = 1000.4560546875 Iterations: 256, residual: 4.5527050929194957e-07
# Iteration 181, rho = 1000.4552612304688 Iterations: 256, residual: 4.5453992925104103e-07
# Iteration 182, rho = 1000.4545288085938 Iterations: 256, residual: 4.538158862033015e-07
# Iteration 183, rho = 1000.4537963867188 Iterations: 256, residual: 4.5309940333027043e-07
# Iteration 184, rho = 1000.4530639648438 Iterations: 256, residual: 4.523878942563897e-07
# Iteration 185, rho = 1000.452392578125 Iterations: 256, residual: 4.5168440010456834e-07
# Iteration 186, rho = 1000.45166015625 Iterations: 256, residual: 4.509844870881352e-07
# Iteration 187, rho = 1000.4509887695312 Iterations: 256, residual: 4.502945785134216e-07
# Iteration 188, rho = 1000.4503173828125 Iterations: 256, residual: 4.4960887635170366e-07
# Iteration 189, rho = 1000.4495849609375 Iterations: 256, residual: 4.4892794903717004e-07
# Iteration 190, rho = 1000.4489135742188 Iterations: 256, residual: 4.4825651457358617e-07
# Iteration 191, rho = 1000.4482421875 Iterations: 256, residual: 4.475845116758137e-07
# Iteration 192, rho = 1000.4476318359375 Iterations: 256, residual: 4.46922200580957e-07
# Iteration 193, rho = 1000.4468994140625 Iterations: 256, residual: 4.46266142262175e-07
# Iteration 194, rho = 1000.4462890625 Iterations: 256, residual: 4.456152566945093e-07
# Iteration 195, rho = 1000.445556640625 Iterations: 256, residual: 4.449706239029183e-07
# Iteration 196, rho = 1000.4449462890625 Iterations: 256, residual: 4.443278385224403e-07
# Iteration 197, rho = 1000.4443359375 Iterations: 256, residual: 4.436966491994099e-07
# Iteration 198, rho = 1000.4437255859375 Iterations: 256, residual: 4.430642661645834e-07
# Iteration 199, rho = 1000.443115234375 Iterations: 256, residual: 4.4244137598070665e-07
# Iteration 200, rho = 1000.4424438476562 Iterations: 256, residual: 4.4182263536640676e-07
# Iteration 201, rho = 1000.4418334960938 Iterations: 256, residual: 4.4120650954937446e-07
# Iteration 202, rho = 1000.4412231445312 Iterations: 256, residual: 4.4059646597816027e-07
# Iteration 203, rho = 1000.4406127929688 Iterations: 256, residual: 4.3999520471516007e-07
# Iteration 204, rho = 1000.4400634765625 Iterations: 256, residual: 4.3939661509284633e-07
# Iteration 205, rho = 1000.4393920898438 Iterations: 256, residual: 4.388039087643847e-07
# Iteration 206, rho = 1000.4388427734375 Iterations: 256, residual: 4.382131351121643e-07
# Iteration 207, rho = 1000.438232421875 Iterations: 256, residual: 4.376287847662752e-07
# Iteration 208, rho = 1000.4376220703125 Iterations: 256, residual: 4.370501471839816e-07
# Iteration 209, rho = 1000.43701171875 Iterations: 256, residual: 4.364740107121179e-07
# Iteration 210, rho = 1000.4364013671875 Iterations: 256, residual: 4.3589881215666537e-07
# Iteration 211, rho = 1000.4359130859375 Iterations: 256, residual: 4.353352380803699e-07
# Iteration 212, rho = 1000.435302734375 Iterations: 256, residual: 4.347741082710854e-07
# Iteration 213, rho = 1000.434814453125 Iterations: 256, residual: 4.3421388795650273e-07
# Iteration 214, rho = 1000.4342041015625 Iterations: 256, residual: 4.3366151203372283e-07
# Iteration 215, rho = 1000.4337158203125 Iterations: 256, residual: 4.3311428044034983e-07
# Iteration 216, rho = 1000.43310546875 Iterations: 256, residual: 4.325682425587729e-07
# Iteration 217, rho = 1000.4326171875 Iterations: 256, residual: 4.320284006098518e-07
# Iteration 218, rho = 1000.4320068359375 Iterations: 256, residual: 4.3148813233528927e-07
# Iteration 219, rho = 1000.4315185546875 Iterations: 256, residual: 4.3095556634398235e-07
# Iteration 220, rho = 1000.4309692382812 Iterations: 256, residual: 4.30427462561056e-07
# Iteration 221, rho = 1000.430419921875 Iterations: 256, residual: 4.299031957089028e-07
# Iteration 222, rho = 1000.429931640625 Iterations: 256, residual: 4.293810320632474e-07
# Iteration 223, rho = 1000.429443359375 Iterations: 256, residual: 4.2886028950306354e-07
# Iteration 224, rho = 1000.4288330078125 Iterations: 256, residual: 4.2834915348066716e-07
# Iteration 225, rho = 1000.4283447265625 Iterations: 256, residual: 4.278418828107533e-07
# Iteration 226, rho = 1000.4278564453125 Iterations: 256, residual: 4.2733384475468483e-07
# Iteration 227, rho = 1000.4273681640625 Iterations: 256, residual: 4.268306099675101e-07
# Iteration 228, rho = 1000.4268798828125 Iterations: 256, residual: 4.2633166685845936e-07
# Iteration 229, rho = 1000.4263305664062 Iterations: 256, residual: 4.2583548065522336e-07
# Iteration 230, rho = 1000.4258422851562 Iterations: 256, residual: 4.25344751420198e-07
# Iteration 231, rho = 1000.4253540039062 Iterations: 256, residual: 4.248534253292746e-07
# Iteration 232, rho = 1000.4248046875 Iterations: 256, residual: 4.2437036995579547e-07
# Iteration 233, rho = 1000.4243774414062 Iterations: 256, residual: 4.238859787619731e-07
# Iteration 234, rho = 1000.4238891601562 Iterations: 256, residual: 4.234095172250818e-07
# Iteration 235, rho = 1000.4234008789062 Iterations: 256, residual: 4.229336241223791e-07
# Iteration 236, rho = 1000.4229736328125 Iterations: 256, residual: 4.224626763971173e-07
# Iteration 237, rho = 1000.4224853515625 Iterations: 256, residual: 4.219961908802361e-07
# Iteration 238, rho = 1000.4219970703125 Iterations: 256, residual: 4.215314106659207e-07
# Iteration 239, rho = 1000.4215087890625 Iterations: 256, residual: 4.2106853470613714e-07
# Iteration 240, rho = 1000.4210205078125 Iterations: 256, residual: 4.2060872829097207e-07
# Iteration 241, rho = 1000.4205932617188 Iterations: 256, residual: 4.201521051072632e-07
# Iteration 242, rho = 1000.420166015625 Iterations: 256, residual: 4.1970000097535376e-07
# Iteration 243, rho = 1000.419677734375 Iterations: 256, residual: 4.1924764104805945e-07
# Iteration 244, rho = 1000.4192504882812 Iterations: 256, residual: 4.188009370409418e-07
# Iteration 245, rho = 1000.4188232421875 Iterations: 256, residual: 4.1835789943434065e-07
# Iteration 246, rho = 1000.4183349609375 Iterations: 256, residual: 4.179148618277395e-07
# Iteration 247, rho = 1000.4179077148438 Iterations: 256, residual: 4.1747807699721307e-07
# Iteration 248, rho = 1000.41748046875 Iterations: 256, residual: 4.1704339537318447e-07
# Iteration 249, rho = 1000.4170532226562 Iterations: 256, residual: 4.166067810729146e-07
# Iteration 250, rho = 1000.4166259765625 Iterations: 256, residual: 4.1617869328547386e-07
# Iteration 251, rho = 1000.4161376953125 Iterations: 256, residual: 4.157519981617952e-07
# Iteration 252, rho = 1000.415771484375 Iterations: 256, residual: 4.153282588958973e-07
# Iteration 253, rho = 1000.415283203125 Iterations: 256, residual: 4.1490523017273517e-07
# Iteration 254, rho = 1000.4149169921875 Iterations: 256, residual: 4.144868341882102e-07
# Iteration 255, rho = 1000.4144287109375 Iterations: 256, residual: 4.1406855189052294e-07
# Iteration 256, rho = 1000.4140625 Iterations: 256, residual: 4.136547602229257e-07
# Iteration 257, rho = 1000.4136962890625 Iterations: 256, residual: 4.132472213314031e-07

# %%
from diffSPH.v2.plotting import prepVisualizationState, visualizeParticleQuantity
from diffSPH.v2.plotting import exportPlot, postProcessPlot
fig, axis = plt.subplots(1,3, figsize = (12,4), squeeze = False)

visualizationState = prepVisualizationState(perennialState, config, grid = True)
# plotRegions(regions, axis[0,0])
# plotRegions(regions, axis[0,1])

s = 0.25

indexPlot = visualizeParticleQuantity(fig, axis[0,0], config, visualizationState, quantity =
                                      'velocities',
                                      mapping = 'L2', s = s, 
                          scaling = 'lin', gridVisualization=False, cmap = 'viridis', title = 'Velocity', which = 'fluid', plotBoth = False, midPoint = 0, streamLines = False)
quantPlot = visualizeParticleQuantity(fig, axis[0,1], config, visualizationState, quantity = 
                                #       'pressures',
                                      'densities',
                                      mapping = '.y', s = s, 
                          scaling = 'sym', gridVisualization=False, cmap = 'icefire', streamLines = False, operation = None, title = 'Pressure', plotBoth = False, which = 'fluid', midPoint = 1000)

l2Plot = visualizeParticleQuantity(fig, axis[0,2], config, visualizationState, quantity = 
                                      div,
                                      mapping = '.x', s = s, 
                          scaling = 'sym', gridVisualization=False, cmap = 'RdBu', streamLines = False, operation = None, title = 'Divergence', plotBoth = False, which = 'fluid', midPoint = 0)

E_k0 =  (0.5 * particleState['areas'] * particleState['densities'] * torch.linalg.norm(initialVelocities, dim = -1)**2).sum().detach().cpu().numpy()
E_k = (0.5 * torch.sum(perennialState['fluid']['areas'] * perennialState['fluid']['densities'] * torch.linalg.norm(perennialState['fluid']['velocities'], dim = 1)**2)).sum().detach().cpu().numpy()
nu_total = np.log(E_k / E_k0) / (-4 *  perennialState['time'] * k**2 )
Re = u_mag * 2 / nu_total

fig.suptitle(f'step {perennialState["timestep"]}, time {perennialState["time"]:.4g}, dt {perennialState["dt"]:.2e} ptcls: {nx}x{nx} = {nx**2}, $\\alpha = {config["diffusion"]["alpha"]:.2e}$, $\\nu_{{sph}} = {config["diffusion"]["nu_sph"]}$\ndiv: {div.sum():.2f}, $\\rho = {perennialState["fluid"]["densities"].mean().cpu().detach().numpy():.2f}$, E_k0: {E_k0:.2f}, E_k: {E_k:.2f}, $\\nu = {nu_total:.2e}$, $Re = {Re:.4g}$')
# fig.suptitle(f'step {perennialState["timestep"]}, time {perennialState["time"]:.4g}, dt {perennialState["dt"]:.2e} ptcls: {nx}x{nx} = {nx**2}, $\\alpha = {config["diffusion"]["alpha"]:.2e}$, $\\nu_{{sph}} = {config["diffusion"]["nu_sph"]}$\ndiv: {div.sum():.2f}, $\\rho = {perennialState["fluid"]["densities"].mean().cpu().detach().numpy():.2f}$, Incompressible: Iters: {len(perennialState["fluid"]["convergence_density"])}, residual: {perennialState["fluid"]["convergence_density"][-1]:.4e}, Divergence-Free: Iters: {len(perennialState["fluid"]["convergence_divergence"])}, residual: {perennialState["fluid"]["convergence_divergence"][-1]:.4e}\n E_k0: {E_k0:.2f}, E_k: {E_k:.2f}, $\\nu = {nu_total:.2e}$, $Re = {Re:.4g}$')
        # fig.suptitle(f'step {perennialState["timestep"]}, time {perennialState["time"]:.2f}, dt {perennialState["dt"]:.2e} ptcls: {nx}x{nx} = {nx**2}, $\\alpha = {config["diffusion"]["alpha"]}$, $\\nu_{{sph}} = {config["diffusion"]["nu_sph"]}$\ndiv: {div.sum()}, $\\rho = {perennialState["fluid"]["densities"].mean().cpu().detach().numpy():.2f}$')

fig.tight_layout()

# simulationState['fluid']['actualArea'] = simulationState['fluid']['masses'] / simulationState['fluid']['densities']
#
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from diffSPH.v2.simulationSchemes.deltaPlus import checkNaN
priorState = None
for i in tqdm(range(8192)):
    if 'shiftAmount' in perennialState['fluid']:
        del perennialState['fluid']['shiftAmount']
    perennialState, priorState, *updates = integrate(simulationStep, perennialState, config, previousStep= priorState)
    # dx, _ = solveShifting(perennialState, config)
    # numNeighbors = perennialState['fluid']['neighborhood']['numNeighbors']
    # perennialState['fluid']['shiftAmount'] = dx
    # perennialState['fluid']['positions'][numNeighbors > 5] += dx[numNeighbors > 5]
    # if config['compute']['checkNaN']:
        # checkNaN(perennialState['fluid']['positions'], 'positions')
        # checkNaN(perennialState['fluid']['shiftAmount'], 'shiftAmount')
    perennialState['time'] += perennialState['dt']
    perennialState['timestep'] += 1
    print(f'Incompressible: Iters: {len(perennialState["fluid"]["convergence_density"])}, residual: {perennialState["fluid"]["convergence_density"][-1]:.4e}, Divergence-Free: Iters: {len(perennialState["fluid"]["convergence_divergence"])}, residual: {perennialState["fluid"]["convergence_divergence"][-1]:.4e}')

    if i % 16 == 0:
        searchNeighbors(perennialState, config)
        visualizationState = prepVisualizationState(perennialState, config)
        div = computeMomentumEquation(perennialState['fluid'], perennialState['fluid'], perennialState['fluid']['neighborhood'], config)
        
        # div = sphOperationStates(perennialState['fluid'], perennialState['fluid'], (perennialState['fluid']['velocities'], perennialState['fluid']['velocities']), operation = 'divergence', gradientMode='difference', neighborhood=perennialState['fluid']['neighborhood'])
        updatePlot(indexPlot, visualizationState, 'velocities')
        # updatePlot(quantPlot, visualizationState, 'pressures')
        updatePlot(quantPlot, visualizationState, 'pressureIncompressible')
        updatePlot(l2Plot, visualizationState, div)
        
        
        E_k0 =  (0.5 * particleState['areas'] * particleState['densities'] * torch.linalg.norm(initialVelocities, dim = -1)**2).sum().detach().cpu().numpy()
        E_k = (0.5 * torch.sum(perennialState['fluid']['areas'] * perennialState['fluid']['densities'] * torch.linalg.norm(perennialState['fluid']['velocities'], dim = 1)**2)).sum().detach().cpu().numpy()
        nu_total = np.log(E_k / E_k0) / (-4 *  perennialState['time'] * k**2 )
        Re = u_mag * 2 / nu_total

        # fig.suptitle(f'step {perennialState["timestep"]}, time {perennialState["time"]:.4g}, dt {perennialState["dt"]:.2e} ptcls: {nx}x{nx} = {nx**2}, $\\alpha = {config["diffusion"]["alpha"]:.2e}$, $\\nu_{{sph}} = {config["diffusion"]["nu_sph"]}$\ndiv: {div.sum():.2f}, $\\rho = {perennialState["fluid"]["densities"].mean().cpu().detach().numpy():.2f}$, Incompressible: Iters: {len(perennialState["fluid"]["convergence_density"])}, residual: {perennialState["fluid"]["convergence_density"][-1]:.4e}, Divergence-Free: Iters: {len(perennialState["fluid"]["convergence_divergence"])}, residual: {perennialState["fluid"]["convergence_divergence"][-1]:.4e}\n E_k0: {E_k0:.2f}, E_k: {E_k:.2f}, $\\nu = {nu_total:.2e}$, $Re = {Re:.4g}$')
        # fig.suptitle(f'step {perennialState["timestep"]}, time {perennialState["time"]:.2f}, dt {perennialState["dt"]:.2e} ptcls: {nx}x{nx} = {nx**2}, $\\alpha = {config["diffusion"]["alpha"]}$, $\\nu_{{sph}} = {config["diffusion"]["nu_sph"]}$\ndiv: {div.sum()}, $\\rho = {perennialState["fluid"]["densities"].mean().cpu().detach().numpy():.2f}$')

        fig.suptitle(f'step {perennialState["timestep"]}, time {perennialState["time"]:.4g}, dt {perennialState["dt"]:.2e} ptcls: {nx}x{nx} = {nx**2}, $\\alpha = {config["diffusion"]["alpha"]:.2e}$, $\\nu_{{sph}} = {config["diffusion"]["nu_sph"]}$\ndiv: {div.sum():.2f}, $\\rho = {perennialState["fluid"]["densities"].mean().cpu().detach().numpy():.2f}$, E_k0: {E_k0:.2f}, E_k: {E_k:.2f}, $\\nu = {nu_total:.2e}$, $Re = {Re:.4g}$')
        # fig.suptitle(f'step {perennialSta qte["timestep"]}, time {perennialState["time"]:.2f}, dt {perennialState["dt"]:.2e} ptcls: {nx}x{nx} = {nx**2}, $\\alpha = {config["diffusion"]["alpha"]}$, $\\nu_{{sph}} = {config["diffusion"]["nu_sph"]}$\ndiv: {div.sum()}, $\\rho = {perennialState["fluid"]["densities"].mean().cpu().detach().numpy():.2f}$')

        
        
        fig.canvas.draw()
        fig.canvas.flush_events()
        exportPlot(perennialState, config, fig)
# Out:
#   0%|          | 0/8192 [00:00<?, ?it/s]
# Incompressible: Iters: 2, residual: 4.1323e-07, Divergence-Free: Iters: 2, residual: 3.8905e-06
# Incompressible: Iters: 2, residual: 4.1321e-07, Divergence-Free: Iters: 3, residual: 9.6966e-06
# Incompressible: Iters: 2, residual: 4.1320e-07, Divergence-Free: Iters: 9, residual: 9.9576e-06
# Incompressible: Iters: 2, residual: 4.1319e-07, Divergence-Free: Iters: 2, residual: 9.5117e-06
# Incompressible: Iters: 2, residual: 4.1319e-07, Divergence-Free: Iters: 2, residual: 7.5220e-06
# Incompressible: Iters: 2, residual: 4.1317e-07, Divergence-Free: Iters: 2, residual: 3.7819e-06
# Incompressible: Iters: 2, residual: 4.1315e-07, Divergence-Free: Iters: 2, residual: 9.4744e-08
# Incompressible: Iters: 2, residual: 4.1312e-07, Divergence-Free: Iters: 2, residual: 2.5262e-06
# Incompressible: Iters: 2, residual: 4.1308e-07, Divergence-Free: Iters: 2, residual: 8.6385e-06
# Incompressible: Iters: 2, residual: 4.1303e-07, Divergence-Free: Iters: 9, residual: 9.8634e-06
# Incompressible: Iters: 2, residual: 4.1297e-07, Divergence-Free: Iters: 3, residual: 9.5401e-06
# Incompressible: Iters: 2, residual: 4.1289e-07, Divergence-Free: Iters: 2, residual: 7.2152e-06
# Incompressible: Iters: 2, residual: 4.1281e-07, Divergence-Free: Iters: 2, residual: 2.8519e-06
# Incompressible: Iters: 2, residual: 4.1272e-07, Divergence-Free: Iters: 2, residual: 5.1887e-07
# Incompressible: Iters: 2, residual: 4.1262e-07, Divergence-Free: Iters: 2, residual: 8.8440e-06
# Incompressible: Iters: 2, residual: 4.1250e-07, Divergence-Free: Iters: 15, residual: 9.6524e-06
# Incompressible: Iters: 2, residual: 4.1237e-07, Divergence-Free: Iters: 6, residual: 9.8870e-06
# Incompressible: Iters: 2, residual: 4.1224e-07, Divergence-Free: Iters: 4, residual: 9.4678e-06
# Incompressible: Iters: 2, residual: 4.1208e-07, Divergence-Free: Iters: 2, residual: 8.3926e-06
# Incompressible: Iters: 2, residual: 4.1193e-07, Divergence-Free: Iters: 2, residual: 5.8175e-06
# Incompressible: Iters: 2, residual: 4.1175e-07, Divergence-Free: Iters: 2, residual: 2.1311e-06
# Incompressible: Iters: 2, residual: 4.1157e-07, Divergence-Free: Iters: 2, residual: 1.8151e-06
# Incompressible: Iters: 2, residual: 4.1137e-07, Divergence-Free: Iters: 2, residual: 6.6791e-06
# Incompressible: Iters: 2, residual: 4.1115e-07, Divergence-Free: Iters: 7, residual: 9.7290e-06
# Incompressible: Iters: 2, residual: 4.1093e-07, Divergence-Free: Iters: 6, residual: 9.8643e-06
# Incompressible: Iters: 2, residual: 4.1069e-07, Divergence-Free: Iters: 2, residual: 9.1053e-06
# Incompressible: Iters: 2, residual: 4.1044e-07, Divergence-Free: Iters: 2, residual: 7.0092e-06
# Incompressible: Iters: 2, residual: 4.1017e-07, Divergence-Free: Iters: 2, residual: 4.7954e-06
# Incompressible: Iters: 2, residual: 4.0990e-07, Divergence-Free: Iters: 2, residual: 7.1595e-06
# Incompressible: Iters: 2, residual: 4.0962e-07, Divergence-Free: Iters: 10, residual: 9.5065e-06
# Incompressible: Iters: 2, residual: 4.0933e-07, Divergence-Free: Iters: 11, residual: 9.5201e-06
# Incompressible: Iters: 2, residual: 4.0903e-07, Divergence-Free: Iters: 6, residual: 9.6281e-06
# Incompressible: Iters: 2, residual: 4.0871e-07, Divergence-Free: Iters: 4, residual: 9.5899e-06
# Incompressible: Iters: 2, residual: 4.0839e-07, Divergence-Free: Iters: 2, residual: 9.5103e-06
# Incompressible: Iters: 2, residual: 4.0805e-07, Divergence-Free: Iters: 2, residual: 8.6474e-06
# Incompressible: Iters: 2, residual: 4.0773e-07, Divergence-Free: Iters: 2, residual: 7.7101e-06
# Incompressible: Iters: 2, residual: 4.0739e-07, Divergence-Free: Iters: 2, residual: 8.7576e-06
# Incompressible: Iters: 2, residual: 4.0706e-07, Divergence-Free: Iters: 6, residual: 9.8885e-06
# Incompressible: Iters: 2, residual: 4.0671e-07, Divergence-Free: Iters: 7, residual: 9.6778e-06
# Incompressible: Iters: 2, residual: 4.0632e-07, Divergence-Free: Iters: 5, residual: 9.5187e-06
# Incompressible: Iters: 2, residual: 4.0593e-07, Divergence-Free: Iters: 4, residual: 9.7813e-06
# Incompressible: Iters: 2, residual: 4.0550e-07, Divergence-Free: Iters: 5, residual: 9.6266e-06
# Incompressible: Iters: 2, residual: 4.0507e-07, Divergence-Free: Iters: 6, residual: 9.6539e-06
# Incompressible: Iters: 2, residual: 4.0463e-07, Divergence-Free: Iters: 9, residual: 9.5066e-06
# Incompressible: Iters: 2, residual: 4.0419e-07, Divergence-Free: Iters: 9, residual: 9.5207e-06
# Incompressible: Iters: 2, residual: 4.0373e-07, Divergence-Free: Iters: 7, residual: 9.9152e-06
# Incompressible: Iters: 2, residual: 4.0325e-07, Divergence-Free: Iters: 6, residual: 9.8888e-06
# Incompressible: Iters: 2, residual: 4.0278e-07, Divergence-Free: Iters: 5, residual: 9.4443e-06
# Incompressible: Iters: 2, residual: 4.0230e-07, Divergence-Free: Iters: 3, residual: 9.5898e-06
# Incompressible: Iters: 2, residual: 4.0184e-07, Divergence-Free: Iters: 4, residual: 9.7109e-06
# Incompressible: Iters: 2, residual: 4.0139e-07, Divergence-Free: Iters: 5, residual: 9.7033e-06
# Incompressible: Iters: 2, residual: 4.0094e-07, Divergence-Free: Iters: 5, residual: 9.8483e-06
# Incompressible: Iters: 2, residual: 4.0049e-07, Divergence-Free: Iters: 6, residual: 9.5282e-06
# Incompressible: Iters: 2, residual: 4.0000e-07, Divergence-Free: Iters: 5, residual: 9.4649e-06
# Incompressible: Iters: 2, residual: 3.9950e-07, Divergence-Free: Iters: 5, residual: 9.9673e-06
# Incompressible: Iters: 2, residual: 3.9898e-07, Divergence-Free: Iters: 7, residual: 9.7008e-06
# Incompressible: Iters: 2, residual: 3.9846e-07, Divergence-Free: Iters: 7, residual: 9.6967e-06
# Incompressible: Iters: 2, residual: 3.9793e-07, Divergence-Free: Iters: 8, residual: 9.9246e-06
# Incompressible: Iters: 2, residual: 3.9741e-07, Divergence-Free: Iters: 8, residual: 9.8062e-06
# Incompressible: Iters: 2, residual: 3.9687e-07, Divergence-Free: Iters: 7, residual: 9.4480e-06
# Incompressible: Iters: 2, residual: 3.9634e-07, Divergence-Free: Iters: 5, residual: 9.6984e-06
# Incompressible: Iters: 2, residual: 3.9581e-07, Divergence-Free: Iters: 5, residual: 9.7908e-06
# Incompressible: Iters: 2, residual: 3.9530e-07, Divergence-Free: Iters: 4, residual: 9.9860e-06
# Incompressible: Iters: 2, residual: 3.9480e-07, Divergence-Free: Iters: 5, residual: 9.8506e-06
# Incompressible: Iters: 2, residual: 3.9431e-07, Divergence-Free: Iters: 5, residual: 9.8796e-06
# Incompressible: Iters: 2, residual: 3.9383e-07, Divergence-Free: Iters: 6, residual: 9.6597e-06
# Incompressible: Iters: 2, residual: 3.9336e-07, Divergence-Free: Iters: 5, residual: 9.8485e-06
# Incompressible: Iters: 2, residual: 3.9287e-07, Divergence-Free: Iters: 6, residual: 9.7092e-06
# Incompressible: Iters: 2, residual: 3.9237e-07, Divergence-Free: Iters: 6, residual: 9.7012e-06
# Incompressible: Iters: 2, residual: 3.9188e-07, Divergence-Free: Iters: 7, residual: 9.6933e-06
# Incompressible: Iters: 2, residual: 3.9139e-07, Divergence-Free: Iters: 8, residual: 9.6581e-06
# Incompressible: Iters: 2, residual: 3.9090e-07, Divergence-Free: Iters: 8, residual: 9.6240e-06
# Incompressible: Iters: 2, residual: 3.9041e-07, Divergence-Free: Iters: 7, residual: 9.7407e-06
# Incompressible: Iters: 2, residual: 3.8993e-07, Divergence-Free: Iters: 6, residual: 9.9790e-06
# Incompressible: Iters: 2, residual: 3.8945e-07, Divergence-Free: Iters: 6, residual: 9.8036e-06
# Incompressible: Iters: 2, residual: 3.8900e-07, Divergence-Free: Iters: 5, residual: 9.5872e-06
# Incompressible: Iters: 2, residual: 3.8856e-07, Divergence-Free: Iters: 4, residual: 9.8793e-06
# Incompressible: Iters: 2, residual: 3.8813e-07, Divergence-Free: Iters: 6, residual: 9.6478e-06
# Incompressible: Iters: 2, residual: 3.8772e-07, Divergence-Free: Iters: 5, residual: 9.6341e-06
# Incompressible: Iters: 2, residual: 3.8732e-07, Divergence-Free: Iters: 5, residual: 9.9248e-06
# Incompressible: Iters: 2, residual: 3.8692e-07, Divergence-Free: Iters: 6, residual: 9.9932e-06
# Incompressible: Iters: 2, residual: 3.8652e-07, Divergence-Free: Iters: 7, residual: 9.5771e-06
# Incompressible: Iters: 2, residual: 3.8614e-07, Divergence-Free: Iters: 6, residual: 9.8011e-06
# Incompressible: Iters: 2, residual: 3.8577e-07, Divergence-Free: Iters: 8, residual: 9.7731e-06
# Incompressible: Iters: 2, residual: 3.8542e-07, Divergence-Free: Iters: 8, residual: 9.5545e-06
# Incompressible: Iters: 2, residual: 3.8508e-07, Divergence-Free: Iters: 7, residual: 9.5770e-06
# Incompressible: Iters: 2, residual: 3.8476e-07, Divergence-Free: Iters: 6, residual: 9.9984e-06
# Incompressible: Iters: 2, residual: 3.8444e-07, Divergence-Free: Iters: 7, residual: 9.8567e-06
# Incompressible: Iters: 2, residual: 3.8413e-07, Divergence-Free: Iters: 5, residual: 9.9573e-06
# Incompressible: Iters: 2, residual: 3.8384e-07, Divergence-Free: Iters: 6, residual: 9.7196e-06
# Incompressible: Iters: 2, residual: 3.8355e-07, Divergence-Free: Iters: 5, residual: 9.7335e-06
# Incompressible: Iters: 2, residual: 3.8328e-07, Divergence-Free: Iters: 5, residual: 9.9149e-06
# Incompressible: Iters: 2, residual: 3.8303e-07, Divergence-Free: Iters: 6, residual: 9.7205e-06
# Incompressible: Iters: 2, residual: 3.8278e-07, Divergence-Free: Iters: 5, residual: 9.7968e-06
# Incompressible: Iters: 2, residual: 3.8254e-07, Divergence-Free: Iters: 6, residual: 9.8509e-06
# Incompressible: Iters: 2, residual: 3.8231e-07, Divergence-Free: Iters: 7, residual: 9.6742e-06
# Incompressible: Iters: 2, residual: 3.8209e-07, Divergence-Free: Iters: 7, residual: 9.8211e-06
# Incompressible: Iters: 2, residual: 3.8190e-07, Divergence-Free: Iters: 8, residual: 9.8421e-06
# Incompressible: Iters: 2, residual: 3.8172e-07, Divergence-Free: Iters: 8, residual: 9.7016e-06
# Incompressible: Iters: 2, residual: 3.8156e-07, Divergence-Free: Iters: 7, residual: 9.7296e-06
# Incompressible: Iters: 2, residual: 3.8141e-07, Divergence-Free: Iters: 6, residual: 9.9903e-06
# Incompressible: Iters: 2, residual: 3.8128e-07, Divergence-Free: Iters: 7, residual: 9.7569e-06
# Incompressible: Iters: 2, residual: 3.8116e-07, Divergence-Free: Iters: 5, residual: 9.7791e-06
# Incompressible: Iters: 2, residual: 3.8105e-07, Divergence-Free: Iters: 5, residual: 9.9748e-06
# Incompressible: Iters: 2, residual: 3.8096e-07, Divergence-Free: Iters: 6, residual: 9.8900e-06
# Incompressible: Iters: 2, residual: 3.8087e-07, Divergence-Free: Iters: 5, residual: 9.9632e-06
# Incompressible: Iters: 2, residual: 3.8079e-07, Divergence-Free: Iters: 6, residual: 9.9191e-06
# Incompressible: Iters: 2, residual: 3.8071e-07, Divergence-Free: Iters: 6, residual: 9.9152e-06
# Incompressible: Iters: 2, residual: 3.8063e-07, Divergence-Free: Iters: 7, residual: 9.7741e-06
# Incompressible: Iters: 2, residual: 3.8056e-07, Divergence-Free: Iters: 7, residual: 9.8114e-06
# Incompressible: Iters: 2, residual: 3.8050e-07, Divergence-Free: Iters: 8, residual: 9.7841e-06
# Incompressible: Iters: 2, residual: 3.8044e-07, Divergence-Free: Iters: 8, residual: 9.6772e-06
# Incompressible: Iters: 2, residual: 3.8039e-07, Divergence-Free: Iters: 7, residual: 9.8211e-06
# Incompressible: Iters: 2, residual: 3.8035e-07, Divergence-Free: Iters: 7, residual: 9.8941e-06
# Incompressible: Iters: 2, residual: 3.8031e-07, Divergence-Free: Iters: 6, residual: 9.9986e-06
# Incompressible: Iters: 2, residual: 3.8029e-07, Divergence-Free: Iters: 6, residual: 9.9129e-06
# Incompressible: Iters: 2, residual: 3.8028e-07, Divergence-Free: Iters: 6, residual: 9.7094e-06
# Incompressible: Iters: 2, residual: 3.8028e-07, Divergence-Free: Iters: 5, residual: 9.8744e-06
# Incompressible: Iters: 2, residual: 3.8030e-07, Divergence-Free: Iters: 7, residual: 9.7394e-06
# Incompressible: Iters: 2, residual: 3.8032e-07, Divergence-Free: Iters: 6, residual: 9.7892e-06
# Incompressible: Iters: 2, residual: 3.8036e-07, Divergence-Free: Iters: 7, residual: 9.7485e-06
# Incompressible: Iters: 2, residual: 3.8041e-07, Divergence-Free: Iters: 7, residual: 9.7607e-06
# Incompressible: Iters: 2, residual: 3.8047e-07, Divergence-Free: Iters: 7, residual: 9.7619e-06
# Incompressible: Iters: 2, residual: 3.8054e-07, Divergence-Free: Iters: 7, residual: 9.7457e-06
# Incompressible: Iters: 2, residual: 3.8061e-07, Divergence-Free: Iters: 7, residual: 9.7957e-06
# Incompressible: Iters: 2, residual: 3.8068e-07, Divergence-Free: Iters: 7, residual: 9.8890e-06
# Incompressible: Iters: 2, residual: 3.8075e-07, Divergence-Free: Iters: 7, residual: 9.9546e-06
# Incompressible: Iters: 2, residual: 3.8082e-07, Divergence-Free: Iters: 7, residual: 9.8862e-06
# Incompressible: Iters: 2, residual: 3.8090e-07, Divergence-Free: Iters: 7, residual: 9.7650e-06
# Incompressible: Iters: 2, residual: 3.8098e-07, Divergence-Free: Iters: 6, residual: 9.8233e-06
# Incompressible: Iters: 2, residual: 3.8108e-07, Divergence-Free: Iters: 6, residual: 9.8841e-06
# Incompressible: Iters: 2, residual: 3.8118e-07, Divergence-Free: Iters: 6, residual: 9.9366e-06
# Incompressible: Iters: 2, residual: 3.8129e-07, Divergence-Free: Iters: 6, residual: 9.9797e-06
# Incompressible: Iters: 2, residual: 3.8142e-07, Divergence-Free: Iters: 7, residual: 9.8007e-06
# Incompressible: Iters: 2, residual: 3.8155e-07, Divergence-Free: Iters: 6, residual: 9.8495e-06
# Incompressible: Iters: 2, residual: 3.8167e-07, Divergence-Free: Iters: 7, residual: 9.9759e-06
# Incompressible: Iters: 2, residual: 3.8180e-07, Divergence-Free: Iters: 8, residual: 9.8954e-06
# Incompressible: Iters: 2, residual: 3.8194e-07, Divergence-Free: Iters: 7, residual: 9.9677e-06
# Incompressible: Iters: 2, residual: 3.8207e-07, Divergence-Free: Iters: 8, residual: 9.8607e-06
# Incompressible: Iters: 2, residual: 3.8220e-07, Divergence-Free: Iters: 7, residual: 9.7873e-06
# Incompressible: Iters: 2, residual: 3.8233e-07, Divergence-Free: Iters: 6, residual: 9.9346e-06
# Incompressible: Iters: 2, residual: 3.8247e-07, Divergence-Free: Iters: 7, residual: 9.9148e-06
# Incompressible: Iters: 2, residual: 3.8260e-07, Divergence-Free: Iters: 7, residual: 9.8106e-06
# Incompressible: Iters: 2, residual: 3.8273e-07, Divergence-Free: Iters: 6, residual: 9.8827e-06
# Incompressible: Iters: 2, residual: 3.8287e-07, Divergence-Free: Iters: 7, residual: 9.8670e-06
# Incompressible: Iters: 2, residual: 3.8301e-07, Divergence-Free: Iters: 7, residual: 9.8339e-06
# Incompressible: Iters: 2, residual: 3.8315e-07, Divergence-Free: Iters: 7, residual: 9.8008e-06
# Incompressible: Iters: 2, residual: 3.8330e-07, Divergence-Free: Iters: 7, residual: 9.8188e-06
# Incompressible: Iters: 2, residual: 3.8345e-07, Divergence-Free: Iters: 7, residual: 9.8823e-06
# Incompressible: Iters: 2, residual: 3.8360e-07, Divergence-Free: Iters: 7, residual: 9.9667e-06
# Incompressible: Iters: 2, residual: 3.8376e-07, Divergence-Free: Iters: 8, residual: 9.8463e-06
# Incompressible: Iters: 2, residual: 3.8393e-07, Divergence-Free: Iters: 7, residual: 9.7947e-06
# Incompressible: Iters: 2, residual: 3.8410e-07, Divergence-Free: Iters: 7, residual: 9.8280e-06
# Incompressible: Iters: 2, residual: 3.8427e-07, Divergence-Free: Iters: 7, residual: 9.8545e-06
# Incompressible: Iters: 2, residual: 3.8444e-07, Divergence-Free: Iters: 7, residual: 9.8657e-06
# Incompressible: Iters: 2, residual: 3.8461e-07, Divergence-Free: Iters: 7, residual: 9.8379e-06
# Incompressible: Iters: 2, residual: 3.8479e-07, Divergence-Free: Iters: 6, residual: 9.9943e-06
# Incompressible: Iters: 2, residual: 3.8497e-07, Divergence-Free: Iters: 8, residual: 9.8670e-06
# Incompressible: Iters: 2, residual: 3.8516e-07, Divergence-Free: Iters: 6, residual: 9.9594e-06
# Incompressible: Iters: 2, residual: 3.8534e-07, Divergence-Free: Iters: 8, residual: 9.8117e-06
# Incompressible: Iters: 2, residual: 3.8553e-07, Divergence-Free: Iters: 6, residual: 9.9047e-06
# Incompressible: Iters: 2, residual: 3.8571e-07, Divergence-Free: Iters: 7, residual: 9.9716e-06
# Incompressible: Iters: 2, residual: 3.8589e-07, Divergence-Free: Iters: 8, residual: 9.8491e-06
# Incompressible: Iters: 2, residual: 3.8607e-07, Divergence-Free: Iters: 7, residual: 9.8232e-06
# Incompressible: Iters: 2, residual: 3.8624e-07, Divergence-Free: Iters: 7, residual: 9.9262e-06
# Incompressible: Iters: 2, residual: 3.8641e-07, Divergence-Free: Iters: 8, residual: 9.8222e-06
# Incompressible: Iters: 2, residual: 3.8656e-07, Divergence-Free: Iters: 6, residual: 9.9371e-06
# Incompressible: Iters: 2, residual: 3.8672e-07, Divergence-Free: Iters: 8, residual: 9.8293e-06
# Incompressible: Iters: 2, residual: 3.8687e-07, Divergence-Free: Iters: 6, residual: 9.9272e-06
# Incompressible: Iters: 2, residual: 3.8702e-07, Divergence-Free: Iters: 8, residual: 9.8174e-06
# Incompressible: Iters: 2, residual: 3.8717e-07, Divergence-Free: Iters: 6, residual: 9.9003e-06
# Incompressible: Iters: 2, residual: 3.8732e-07, Divergence-Free: Iters: 7, residual: 9.9377e-06
# Incompressible: Iters: 2, residual: 3.8746e-07, Divergence-Free: Iters: 7, residual: 9.9286e-06
# Incompressible: Iters: 2, residual: 3.8761e-07, Divergence-Free: Iters: 7, residual: 9.9799e-06
# Incompressible: Iters: 2, residual: 3.8776e-07, Divergence-Free: Iters: 8, residual: 9.8768e-06
# Incompressible: Iters: 2, residual: 3.8791e-07, Divergence-Free: Iters: 7, residual: 9.9321e-06
# Incompressible: Iters: 2, residual: 3.8806e-07, Divergence-Free: Iters: 8, residual: 9.9412e-06
# Incompressible: Iters: 2, residual: 3.8821e-07, Divergence-Free: Iters: 8, residual: 9.8757e-06
# Incompressible: Iters: 2, residual: 3.8837e-07, Divergence-Free: Iters: 7, residual: 9.9559e-06
# Incompressible: Iters: 2, residual: 3.8852e-07, Divergence-Free: Iters: 8, residual: 9.8790e-06
# Incompressible: Iters: 2, residual: 3.8868e-07, Divergence-Free: Iters: 7, residual: 9.8590e-06
# Incompressible: Iters: 2, residual: 3.8884e-07, Divergence-Free: Iters: 7, residual: 9.8863e-06
# Incompressible: Iters: 2, residual: 3.8901e-07, Divergence-Free: Iters: 7, residual: 9.9096e-06
# Incompressible: Iters: 2, residual: 3.8917e-07, Divergence-Free: Iters: 7, residual: 9.9145e-06
# Incompressible: Iters: 2, residual: 3.8934e-07, Divergence-Free: Iters: 7, residual: 9.9187e-06
# Incompressible: Iters: 2, residual: 3.8951e-07, Divergence-Free: Iters: 7, residual: 9.9391e-06
# Incompressible: Iters: 2, residual: 3.8969e-07, Divergence-Free: Iters: 8, residual: 9.8443e-06
# Incompressible: Iters: 2, residual: 3.8988e-07, Divergence-Free: Iters: 7, residual: 9.8966e-06
# Incompressible: Iters: 2, residual: 3.9008e-07, Divergence-Free: Iters: 8, residual: 9.9255e-06
# Incompressible: Iters: 2, residual: 3.9029e-07, Divergence-Free: Iters: 8, residual: 9.9343e-06
# Incompressible: Iters: 2, residual: 3.9051e-07, Divergence-Free: Iters: 8, residual: 9.8946e-06
# Incompressible: Iters: 2, residual: 3.9073e-07, Divergence-Free: Iters: 7, residual: 9.9119e-06
# Incompressible: Iters: 2, residual: 3.9096e-07, Divergence-Free: Iters: 7, residual: 9.9526e-06
# Incompressible: Iters: 2, residual: 3.9119e-07, Divergence-Free: Iters: 8, residual: 9.8552e-06
# Incompressible: Iters: 2, residual: 3.9142e-07, Divergence-Free: Iters: 6, residual: 9.9922e-06
# Incompressible: Iters: 2, residual: 3.9165e-07, Divergence-Free: Iters: 8, residual: 9.9790e-06
# Incompressible: Iters: 2, residual: 3.9189e-07, Divergence-Free: Iters: 8, residual: 9.8646e-06
# Incompressible: Iters: 2, residual: 3.9214e-07, Divergence-Free: Iters: 6, residual: 9.9958e-06
# Incompressible: Iters: 2, residual: 3.9239e-07, Divergence-Free: Iters: 9, residual: 9.8777e-06
# Incompressible: Iters: 2, residual: 3.9264e-07, Divergence-Free: Iters: 7, residual: 9.8618e-06
# Incompressible: Iters: 2, residual: 3.9291e-07, Divergence-Free: Iters: 7, residual: 9.8883e-06
# Incompressible: Iters: 2, residual: 3.9318e-07, Divergence-Free: Iters: 7, residual: 9.9404e-06
# Incompressible: Iters: 2, residual: 3.9346e-07, Divergence-Free: Iters: 8, residual: 9.8894e-06
# Incompressible: Iters: 2, residual: 3.9375e-07, Divergence-Free: Iters: 7, residual: 9.8963e-06
# Incompressible: Iters: 2, residual: 3.9405e-07, Divergence-Free: Iters: 7, residual: 9.9590e-06
# Incompressible: Iters: 2, residual: 3.9435e-07, Divergence-Free: Iters: 8, residual: 9.9423e-06
# Incompressible: Iters: 2, residual: 3.9465e-07, Divergence-Free: Iters: 8, residual: 9.8755e-06
# Incompressible: Iters: 2, residual: 3.9496e-07, Divergence-Free: Iters: 7, residual: 9.9443e-06
# Incompressible: Iters: 2, residual: 3.9527e-07, Divergence-Free: Iters: 8, residual: 9.9360e-06
# Incompressible: Iters: 2, residual: 3.9558e-07, Divergence-Free: Iters: 7, residual: 9.9840e-06
# Incompressible: Iters: 2, residual: 3.9588e-07, Divergence-Free: Iters: 8, residual: 9.9412e-06
# Incompressible: Iters: 2, residual: 3.9619e-07, Divergence-Free: Iters: 7, residual: 9.9197e-06
# Incompressible: Iters: 2, residual: 3.9650e-07, Divergence-Free: Iters: 7, residual: 9.9125e-06
# Incompressible: Iters: 2, residual: 3.9681e-07, Divergence-Free: Iters: 7, residual: 9.9532e-06
# Incompressible: Iters: 2, residual: 3.9711e-07, Divergence-Free: Iters: 8, residual: 9.8879e-06
# Incompressible: Iters: 2, residual: 3.9741e-07, Divergence-Free: Iters: 7, residual: 9.8973e-06
# Incompressible: Iters: 2, residual: 3.9770e-07, Divergence-Free: Iters: 8, residual: 9.9108e-06
# Incompressible: Iters: 2, residual: 3.9798e-07, Divergence-Free: Iters: 7, residual: 9.9958e-06
# Incompressible: Iters: 2, residual: 3.9826e-07, Divergence-Free: Iters: 8, residual: 9.9580e-06
# Incompressible: Iters: 2, residual: 3.9852e-07, Divergence-Free: Iters: 7, residual: 9.9601e-06
# Incompressible: Iters: 2, residual: 3.9878e-07, Divergence-Free: Iters: 7, residual: 9.9917e-06
# Incompressible: Iters: 2, residual: 3.9902e-07, Divergence-Free: Iters: 8, residual: 9.9189e-06
# Incompressible: Iters: 2, residual: 3.9926e-07, Divergence-Free: Iters: 7, residual: 9.9413e-06
# Incompressible: Iters: 2, residual: 3.9948e-07, Divergence-Free: Iters: 8, residual: 9.8927e-06
# Incompressible: Iters: 2, residual: 3.9971e-07, Divergence-Free: Iters: 7, residual: 9.9083e-06
# Incompressible: Iters: 2, residual: 3.9992e-07, Divergence-Free: Iters: 7, residual: 9.9540e-06
# Incompressible: Iters: 2, residual: 4.0013e-07, Divergence-Free: Iters: 8, residual: 9.9011e-06
# Incompressible: Iters: 2, residual: 4.0034e-07, Divergence-Free: Iters: 7, residual: 9.9295e-06
# Incompressible: Iters: 2, residual: 4.0054e-07, Divergence-Free: Iters: 8, residual: 9.9119e-06
# Incompressible: Iters: 2, residual: 4.0074e-07, Divergence-Free: Iters: 7, residual: 9.9813e-06
# Incompressible: Iters: 2, residual: 4.0093e-07, Divergence-Free: Iters: 8, residual: 9.9552e-06
# Incompressible: Iters: 2, residual: 4.0113e-07, Divergence-Free: Iters: 8, residual: 9.8885e-06
# Incompressible: Iters: 2, residual: 4.0132e-07, Divergence-Free: Iters: 7, residual: 9.9102e-06
# Incompressible: Iters: 2, residual: 4.0150e-07, Divergence-Free: Iters: 8, residual: 9.9079e-06
# Incompressible: Iters: 2, residual: 4.0168e-07, Divergence-Free: Iters: 8, residual: 9.9053e-06
# Incompressible: Iters: 2, residual: 4.0186e-07, Divergence-Free: Iters: 8, residual: 9.8911e-06
# Incompressible: Iters: 2, residual: 4.0203e-07, Divergence-Free: Iters: 7, residual: 9.9795e-06
# Incompressible: Iters: 2, residual: 4.0221e-07, Divergence-Free: Iters: 9, residual: 9.9029e-06
# Incompressible: Iters: 2, residual: 4.0237e-07, Divergence-Free: Iters: 6, residual: 9.9904e-06
# Incompressible: Iters: 2, residual: 4.0253e-07, Divergence-Free: Iters: 8, residual: 9.9672e-06
# Incompressible: Iters: 2, residual: 4.0269e-07, Divergence-Free: Iters: 7, residual: 9.9847e-06
# Incompressible: Iters: 2, residual: 4.0284e-07, Divergence-Free: Iters: 8, residual: 9.8947e-06
# Incompressible: Iters: 2, residual: 4.0299e-07, Divergence-Free: Iters: 7, residual: 9.8970e-06
# Incompressible: Iters: 2, residual: 4.0312e-07, Divergence-Free: Iters: 7, residual: 9.9483e-06
# Incompressible: Iters: 2, residual: 4.0325e-07, Divergence-Free: Iters: 8, residual: 9.9144e-06
# Incompressible: Iters: 2, residual: 4.0337e-07, Divergence-Free: Iters: 7, residual: 9.9426e-06
# Incompressible: Iters: 2, residual: 4.0348e-07, Divergence-Free: Iters: 8, residual: 9.9022e-06
# Incompressible: Iters: 2, residual: 4.0358e-07, Divergence-Free: Iters: 7, residual: 9.9420e-06
# Incompressible: Iters: 2, residual: 4.0369e-07, Divergence-Free: Iters: 8, residual: 9.9352e-06
# Incompressible: Iters: 2, residual: 4.0378e-07, Divergence-Free: Iters: 8, residual: 9.8949e-06
# Incompressible: Iters: 2, residual: 4.0388e-07, Divergence-Free: Iters: 7, residual: 9.9968e-06
# Incompressible: Iters: 2, residual: 4.0398e-07, Divergence-Free: Iters: 9, residual: 9.9545e-06
# Incompressible: Iters: 2, residual: 4.0408e-07, Divergence-Free: Iters: 8, residual: 9.9114e-06
# Incompressible: Iters: 2, residual: 4.0418e-07, Divergence-Free: Iters: 7, residual: 9.9837e-06
# Incompressible: Iters: 2, residual: 4.0429e-07, Divergence-Free: Iters: 9, residual: 9.9019e-06
# Incompressible: Iters: 2, residual: 4.0440e-07, Divergence-Free: Iters: 7, residual: 9.8953e-06
# Incompressible: Iters: 2, residual: 4.0452e-07, Divergence-Free: Iters: 7, residual: 9.9347e-06
# Incompressible: Iters: 2, residual: 4.0464e-07, Divergence-Free: Iters: 8, residual: 9.9123e-06
# Incompressible: Iters: 2, residual: 4.0476e-07, Divergence-Free: Iters: 7, residual: 9.9425e-06
# Incompressible: Iters: 2, residual: 4.0488e-07, Divergence-Free: Iters: 7, residual: 9.9975e-06
# Incompressible: Iters: 2, residual: 4.0500e-07, Divergence-Free: Iters: 8, residual: 9.9476e-06
# Incompressible: Iters: 2, residual: 4.0512e-07, Divergence-Free: Iters: 7, residual: 9.9705e-06
# Incompressible: Iters: 2, residual: 4.0523e-07, Divergence-Free: Iters: 8, residual: 9.9349e-06
# Incompressible: Iters: 2, residual: 4.0533e-07, Divergence-Free: Iters: 7, residual: 9.9892e-06
# Incompressible: Iters: 2, residual: 4.0543e-07, Divergence-Free: Iters: 9, residual: 9.9039e-06
# Incompressible: Iters: 2, residual: 4.0552e-07, Divergence-Free: Iters: 7, residual: 9.9470e-06
# Incompressible: Iters: 2, residual: 4.0561e-07, Divergence-Free: Iters: 8, residual: 9.9526e-06
# Incompressible: Iters: 2, residual: 4.0569e-07, Divergence-Free: Iters: 8, residual: 9.9531e-06
# Incompressible: Iters: 2, residual: 4.0578e-07, Divergence-Free: Iters: 8, residual: 9.9279e-06
# Incompressible: Iters: 2, residual: 4.0586e-07, Divergence-Free: Iters: 7, residual: 9.9874e-06
# Incompressible: Iters: 2, residual: 4.0595e-07, Divergence-Free: Iters: 8, residual: 9.9697e-06
# Incompressible: Iters: 2, residual: 4.0604e-07, Divergence-Free: Iters: 8, residual: 9.9146e-06
# Incompressible: Iters: 2, residual: 4.0613e-07, Divergence-Free: Iters: 7, residual: 9.9477e-06
# Incompressible: Iters: 2, residual: 4.0623e-07, Divergence-Free: Iters: 8, residual: 9.9311e-06
# Incompressible: Iters: 2, residual: 4.0632e-07, Divergence-Free: Iters: 8, residual: 9.9007e-06
# Incompressible: Iters: 2, residual: 4.0641e-07, Divergence-Free: Iters: 7, residual: 9.9956e-06
# Incompressible: Iters: 2, residual: 4.0649e-07, Divergence-Free: Iters: 9, residual: 9.9350e-06
# Incompressible: Iters: 2, residual: 4.0657e-07, Divergence-Free: Iters: 7, residual: 9.9507e-06
# Incompressible: Iters: 2, residual: 4.0664e-07, Divergence-Free: Iters: 8, residual: 9.9308e-06
# Incompressible: Iters: 2, residual: 4.0671e-07, Divergence-Free: Iters: 7, residual: 9.9864e-06
# Incompressible: Iters: 2, residual: 4.0676e-07, Divergence-Free: Iters: 8, residual: 9.9834e-06
# Incompressible: Iters: 2, residual: 4.0681e-07, Divergence-Free: Iters: 7, residual: 9.9770e-06
# Incompressible: Iters: 2, residual: 4.0685e-07, Divergence-Free: Iters: 7, residual: 9.9851e-06
# Incompressible: Iters: 2, residual: 4.0688e-07, Divergence-Free: Iters: 8, residual: 9.9078e-06
# Incompressible: Iters: 2, residual: 4.0691e-07, Divergence-Free: Iters: 7, residual: 9.9185e-06
# Incompressible: Iters: 2, residual: 4.0694e-07, Divergence-Free: Iters: 8, residual: 9.9122e-06
# Incompressible: Iters: 2, residual: 4.0697e-07, Divergence-Free: Iters: 7, residual: 9.9712e-06
# Incompressible: Iters: 2, residual: 4.0700e-07, Divergence-Free: Iters: 8, residual: 9.9856e-06
# Incompressible: Iters: 2, residual: 4.0704e-07, Divergence-Free: Iters: 9, residual: 9.9194e-06
# Incompressible: Iters: 2, residual: 4.0707e-07, Divergence-Free: Iters: 8, residual: 9.9161e-06
# Incompressible: Iters: 2, residual: 4.0710e-07, Divergence-Free: Iters: 8, residual: 9.9418e-06
# Incompressible: Iters: 2, residual: 4.0713e-07, Divergence-Free: Iters: 8, residual: 9.9872e-06
# Incompressible: Iters: 2, residual: 4.0716e-07, Divergence-Free: Iters: 9, residual: 9.9476e-06
# Incompressible: Iters: 2, residual: 4.0719e-07, Divergence-Free: Iters: 8, residual: 9.9090e-06
# Incompressible: Iters: 2, residual: 4.0722e-07, Divergence-Free: Iters: 7, residual: 9.9847e-06
# Incompressible: Iters: 2, residual: 4.0724e-07, Divergence-Free: Iters: 9, residual: 9.9376e-06
# Incompressible: Iters: 2, residual: 4.0726e-07, Divergence-Free: Iters: 7, residual: 9.9767e-06
# Incompressible: Iters: 2, residual: 4.0728e-07, Divergence-Free: Iters: 8, residual: 9.9811e-06
# Incompressible: Iters: 2, residual: 4.0729e-07, Divergence-Free: Iters: 8, residual: 9.9513e-06
# Incompressible: Iters: 2, residual: 4.0730e-07, Divergence-Free: Iters: 8, residual: 9.9119e-06
# Incompressible: Iters: 2, residual: 4.0731e-07, Divergence-Free: Iters: 7, residual: 9.9559e-06
# Incompressible: Iters: 2, residual: 4.0733e-07, Divergence-Free: Iters: 8, residual: 9.9704e-06
# Incompressible: Iters: 2, residual: 4.0734e-07, Divergence-Free: Iters: 8, residual: 9.9785e-06
# Incompressible: Iters: 2, residual: 4.0735e-07, Divergence-Free: Iters: 8, residual: 9.9781e-06
# Incompressible: Iters: 2, residual: 4.0736e-07, Divergence-Free: Iters: 8, residual: 9.9512e-06
# Incompressible: Iters: 2, residual: 4.0737e-07, Divergence-Free: Iters: 8, residual: 9.9526e-06
# Incompressible: Iters: 2, residual: 4.0738e-07, Divergence-Free: Iters: 7, residual: 9.9978e-06
# Incompressible: Iters: 2, residual: 4.0739e-07, Divergence-Free: Iters: 8, residual: 9.9982e-06
# Incompressible: Iters: 2, residual: 4.0739e-07, Divergence-Free: Iters: 8, residual: 9.9839e-06
# Incompressible: Iters: 2, residual: 4.0739e-07, Divergence-Free: Iters: 8, residual: 9.9661e-06
# Incompressible: Iters: 2, residual: 4.0739e-07, Divergence-Free: Iters: 8, residual: 9.9223e-06
# Incompressible: Iters: 2, residual: 4.0739e-07, Divergence-Free: Iters: 7, residual: 9.9837e-06
# Incompressible: Iters: 2, residual: 4.0738e-07, Divergence-Free: Iters: 9, residual: 9.9333e-06
# Incompressible: Iters: 2, residual: 4.0737e-07, Divergence-Free: Iters: 7, residual: 9.9880e-06
# Incompressible: Iters: 2, residual: 4.0735e-07, Divergence-Free: Iters: 9, residual: 9.9307e-06
# Incompressible: Iters: 2, residual: 4.0733e-07, Divergence-Free: Iters: 7, residual: 9.9663e-06
# Incompressible: Iters: 2, residual: 4.0731e-07, Divergence-Free: Iters: 8, residual: 9.9778e-06
# Incompressible: Iters: 2, residual: 4.0729e-07, Divergence-Free: Iters: 8, residual: 9.9913e-06
# Incompressible: Iters: 2, residual: 4.0726e-07, Divergence-Free: Iters: 9, residual: 9.9176e-06
# Incompressible: Iters: 2, residual: 4.0724e-07, Divergence-Free: Iters: 7, residual: 9.9667e-06
# Incompressible: Iters: 2, residual: 4.0721e-07, Divergence-Free: Iters: 9, residual: 9.9428e-06
# Incompressible: Iters: 2, residual: 4.0719e-07, Divergence-Free: Iters: 8, residual: 9.9487e-06
# Incompressible: Iters: 2, residual: 4.0717e-07, Divergence-Free: Iters: 8, residual: 9.9615e-06
# Incompressible: Iters: 2, residual: 4.0715e-07, Divergence-Free: Iters: 8, residual: 9.9776e-06
# Incompressible: Iters: 2, residual: 4.0714e-07, Divergence-Free: Iters: 9, residual: 9.9219e-06
# Incompressible: Iters: 2, residual: 4.0712e-07, Divergence-Free: Iters: 7, residual: 9.9774e-06
# Incompressible: Iters: 2, residual: 4.0712e-07, Divergence-Free: Iters: 9, residual: 9.9205e-06
# Incompressible: Iters: 2, residual: 4.0711e-07, Divergence-Free: Iters: 7, residual: 9.9393e-06
# Incompressible: Iters: 2, residual: 4.0711e-07, Divergence-Free: Iters: 8, residual: 9.9314e-06
# Incompressible: Iters: 2, residual: 4.0712e-07, Divergence-Free: Iters: 8, residual: 9.9249e-06
# Incompressible: Iters: 2, residual: 4.0712e-07, Divergence-Free: Iters: 8, residual: 9.9163e-06
# Incompressible: Iters: 2, residual: 4.0713e-07, Divergence-Free: Iters: 7, residual: 9.9869e-06
# Incompressible: Iters: 2, residual: 4.0714e-07, Divergence-Free: Iters: 9, residual: 9.9490e-06
# Incompressible: Iters: 2, residual: 4.0714e-07, Divergence-Free: Iters: 7, residual: 9.9889e-06
# Incompressible: Iters: 2, residual: 4.0715e-07, Divergence-Free: Iters: 9, residual: 9.9150e-06
# Incompressible: Iters: 2, residual: 4.0715e-07, Divergence-Free: Iters: 7, residual: 9.9333e-06
# Incompressible: Iters: 2, residual: 4.0715e-07, Divergence-Free: Iters: 8, residual: 9.9278e-06
# Incompressible: Iters: 2, residual: 4.0715e-07, Divergence-Free: Iters: 8, residual: 9.9296e-06
# Incompressible: Iters: 2, residual: 4.0714e-07, Divergence-Free: Iters: 8, residual: 9.9149e-06
# Incompressible: Iters: 2, residual: 4.0714e-07, Divergence-Free: Iters: 7, residual: 9.9564e-06
# Incompressible: Iters: 2, residual: 4.0713e-07, Divergence-Free: Iters: 8, residual: 9.9858e-06
# Incompressible: Iters: 2, residual: 4.0713e-07, Divergence-Free: Iters: 8, residual: 9.9937e-06
# Incompressible: Iters: 2, residual: 4.0712e-07, Divergence-Free: Iters: 8, residual: 9.9918e-06
# Incompressible: Iters: 2, residual: 4.0712e-07, Divergence-Free: Iters: 8, residual: 9.9871e-06
# Incompressible: Iters: 2, residual: 4.0712e-07, Divergence-Free: Iters: 8, residual: 9.9833e-06
# Incompressible: Iters: 2, residual: 4.0713e-07, Divergence-Free: Iters: 9, residual: 9.9665e-06
# Incompressible: Iters: 2, residual: 4.0714e-07, Divergence-Free: Iters: 8, residual: 9.9888e-06
# Incompressible: Iters: 2, residual: 4.0716e-07, Divergence-Free: Iters: 9, residual: 9.9404e-06
# Incompressible: Iters: 2, residual: 4.0718e-07, Divergence-Free: Iters: 8, residual: 9.9453e-06
# Incompressible: Iters: 2, residual: 4.0721e-07, Divergence-Free: Iters: 8, residual: 9.9780e-06
# Incompressible: Iters: 2, residual: 4.0724e-07, Divergence-Free: Iters: 9, residual: 9.9228e-06
# Incompressible: Iters: 2, residual: 4.0727e-07, Divergence-Free: Iters: 7, residual: 9.9556e-06
# Incompressible: Iters: 2, residual: 4.0730e-07, Divergence-Free: Iters: 8, residual: 9.9466e-06
# Incompressible: Iters: 2, residual: 4.0734e-07, Divergence-Free: Iters: 7, residual: 9.9804e-06
# Incompressible: Iters: 2, residual: 4.0738e-07, Divergence-Free: Iters: 8, residual: 9.9827e-06
# Incompressible: Iters: 2, residual: 4.0742e-07, Divergence-Free: Iters: 8, residual: 9.9462e-06
# Incompressible: Iters: 2, residual: 4.0747e-07, Divergence-Free: Iters: 7, residual: 9.9588e-06
# Incompressible: Iters: 2, residual: 4.0753e-07, Divergence-Free: Iters: 8, residual: 9.9544e-06
# Incompressible: Iters: 2, residual: 4.0760e-07, Divergence-Free: Iters: 8, residual: 9.9357e-06
# Incompressible: Iters: 2, residual: 4.0766e-07, Divergence-Free: Iters: 8, residual: 9.9426e-06
# Incompressible: Iters: 2, residual: 4.0773e-07, Divergence-Free: Iters: 8, residual: 9.9508e-06
# Incompressible: Iters: 2, residual: 4.0781e-07, Divergence-Free: Iters: 8, residual: 9.9742e-06
# Incompressible: Iters: 2, residual: 4.0790e-07, Divergence-Free: Iters: 9, residual: 9.9548e-06
# Incompressible: Iters: 2, residual: 4.0798e-07, Divergence-Free: Iters: 8, residual: 9.9478e-06
# Incompressible: Iters: 2, residual: 4.0807e-07, Divergence-Free: Iters: 8, residual: 9.9813e-06
# Incompressible: Iters: 2, residual: 4.0816e-07, Divergence-Free: Iters: 9, residual: 9.9528e-06
# Incompressible: Iters: 2, residual: 4.0825e-07, Divergence-Free: Iters: 8, residual: 9.9545e-06
# Incompressible: Iters: 2, residual: 4.0834e-07, Divergence-Free: Iters: 8, residual: 9.9597e-06
# Incompressible: Iters: 2, residual: 4.0843e-07, Divergence-Free: Iters: 8, residual: 9.9722e-06
# Incompressible: Iters: 2, residual: 4.0852e-07, Divergence-Free: Iters: 8, residual: 9.9701e-06
# Incompressible: Iters: 2, residual: 4.0861e-07, Divergence-Free: Iters: 8, residual: 9.9417e-06
# Incompressible: Iters: 2, residual: 4.0869e-07, Divergence-Free: Iters: 7, residual: 9.9858e-06
# Incompressible: Iters: 2, residual: 4.0877e-07, Divergence-Free: Iters: 9, residual: 9.9242e-06
# Incompressible: Iters: 2, residual: 4.0885e-07, Divergence-Free: Iters: 7, residual: 9.9611e-06
# Incompressible: Iters: 2, residual: 4.0892e-07, Divergence-Free: Iters: 8, residual: 9.9831e-06
# Incompressible: Iters: 2, residual: 4.0899e-07, Divergence-Free: Iters: 8, residual: 9.9957e-06
# Incompressible: Iters: 2, residual: 4.0906e-07, Divergence-Free: Iters: 8, residual: 9.9975e-06
# Incompressible: Iters: 2, residual: 4.0912e-07, Divergence-Free: Iters: 9, residual: 9.9258e-06
# Incompressible: Iters: 2, residual: 4.0919e-07, Divergence-Free: Iters: 7, residual: 9.9908e-06
# Incompressible: Iters: 2, residual: 4.0926e-07, Divergence-Free: Iters: 10, residual: 9.9273e-06
# Incompressible: Iters: 2, residual: 4.0934e-07, Divergence-Free: Iters: 7, residual: 9.9776e-06
# Incompressible: Iters: 2, residual: 4.0942e-07, Divergence-Free: Iters: 9, residual: 9.9401e-06
# Incompressible: Iters: 2, residual: 4.0950e-07, Divergence-Free: Iters: 7, residual: 9.9854e-06
# Incompressible: Iters: 2, residual: 4.0959e-07, Divergence-Free: Iters: 9, residual: 9.9717e-06
# Incompressible: Iters: 2, residual: 4.0967e-07, Divergence-Free: Iters: 8, residual: 9.9749e-06
# Incompressible: Iters: 2, residual: 4.0977e-07, Divergence-Free: Iters: 8, residual: 9.9814e-06
# Incompressible: Iters: 2, residual: 4.0986e-07, Divergence-Free: Iters: 8, residual: 9.9991e-06
# Incompressible: Iters: 2, residual: 4.0996e-07, Divergence-Free: Iters: 9, residual: 9.9508e-06
# Incompressible: Iters: 2, residual: 4.1006e-07, Divergence-Free: Iters: 8, residual: 9.9344e-06
# Incompressible: Iters: 2, residual: 4.1015e-07, Divergence-Free: Iters: 8, residual: 9.9481e-06
# Incompressible: Iters: 2, residual: 4.1024e-07, Divergence-Free: Iters: 8, residual: 9.9862e-06
# Incompressible: Iters: 2, residual: 4.1033e-07, Divergence-Free: Iters: 9, residual: 9.9289e-06
# Incompressible: Iters: 2, residual: 4.1043e-07, Divergence-Free: Iters: 7, residual: 9.9387e-06
# Incompressible: Iters: 2, residual: 4.1051e-07, Divergence-Free: Iters: 7, residual: 9.9910e-06
# Incompressible: Iters: 2, residual: 4.1059e-07, Divergence-Free: Iters: 8, residual: 9.9811e-06
# Incompressible: Iters: 2, residual: 4.1067e-07, Divergence-Free: Iters: 8, residual: 9.9339e-06
# Incompressible: Iters: 2, residual: 4.1073e-07, Divergence-Free: Iters: 7, residual: 9.9604e-06
# Incompressible: Iters: 2, residual: 4.1079e-07, Divergence-Free: Iters: 8, residual: 9.9962e-06
# Incompressible: Iters: 2, residual: 4.1084e-07, Divergence-Free: Iters: 9, residual: 9.9565e-06
# Incompressible: Iters: 2, residual: 4.1089e-07, Divergence-Free: Iters: 8, residual: 9.9525e-06
# Incompressible: Iters: 2, residual: 4.1094e-07, Divergence-Free: Iters: 8, residual: 9.9912e-06
# Incompressible: Iters: 2, residual: 4.1098e-07, Divergence-Free: Iters: 9, residual: 9.9838e-06
# Incompressible: Iters: 2, residual: 4.1103e-07, Divergence-Free: Iters: 9, residual: 9.9473e-06
# Incompressible: Iters: 2, residual: 4.1108e-07, Divergence-Free: Iters: 8, residual: 9.9800e-06
# Incompressible: Iters: 2, residual: 4.1113e-07, Divergence-Free: Iters: 9, residual: 9.9895e-06
# Incompressible: Iters: 2, residual: 4.1119e-07, Divergence-Free: Iters: 9, residual: 9.9656e-06
# Incompressible: Iters: 2, residual: 4.1125e-07, Divergence-Free: Iters: 9, residual: 9.9355e-06
# Incompressible: Iters: 2, residual: 4.1133e-07, Divergence-Free: Iters: 8, residual: 9.9954e-06
# Incompressible: Iters: 2, residual: 4.1140e-07, Divergence-Free: Iters: 10, residual: 9.9454e-06
# Incompressible: Iters: 2, residual: 4.1149e-07, Divergence-Free: Iters: 7, residual: 9.9993e-06
# Incompressible: Iters: 2, residual: 4.1159e-07, Divergence-Free: Iters: 9, residual: 9.9872e-06
# Incompressible: Iters: 2, residual: 4.1169e-07, Divergence-Free: Iters: 9, residual: 9.9419e-06
# Incompressible: Iters: 2, residual: 4.1180e-07, Divergence-Free: Iters: 7, residual: 9.9904e-06
# Incompressible: Iters: 2, residual: 4.1192e-07, Divergence-Free: Iters: 9, residual: 9.9625e-06
# Incompressible: Iters: 2, residual: 4.1204e-07, Divergence-Free: Iters: 8, residual: 9.9301e-06
# Incompressible: Iters: 2, residual: 4.1217e-07, Divergence-Free: Iters: 7, residual: 9.9915e-06
# Incompressible: Iters: 2, residual: 4.1230e-07, Divergence-Free: Iters: 9, residual: 9.9674e-06
# Incompressible: Iters: 2, residual: 4.1243e-07, Divergence-Free: Iters: 7, residual: 9.9866e-06
# Incompressible: Iters: 2, residual: 4.1256e-07, Divergence-Free: Iters: 8, residual: 9.9861e-06
# Incompressible: Iters: 2, residual: 4.1268e-07, Divergence-Free: Iters: 8, residual: 9.9746e-06
# Incompressible: Iters: 2, residual: 4.1280e-07, Divergence-Free: Iters: 8, residual: 9.9785e-06
# Incompressible: Iters: 2, residual: 4.1290e-07, Divergence-Free: Iters: 8, residual: 9.9659e-06
# Incompressible: Iters: 2, residual: 4.1301e-07, Divergence-Free: Iters: 8, residual: 9.9468e-06
# Incompressible: Iters: 2, residual: 4.1310e-07, Divergence-Free: Iters: 8, residual: 9.9354e-06
# Incompressible: Iters: 2, residual: 4.1318e-07, Divergence-Free: Iters: 8, residual: 9.9404e-06
# Incompressible: Iters: 2, residual: 4.1326e-07, Divergence-Free: Iters: 8, residual: 9.9619e-06
# Incompressible: Iters: 2, residual: 4.1332e-07, Divergence-Free: Iters: 9, residual: 9.9428e-06
# Incompressible: Iters: 2, residual: 4.1339e-07, Divergence-Free: Iters: 8, residual: 9.9724e-06
# Incompressible: Iters: 2, residual: 4.1345e-07, Divergence-Free: Iters: 9, residual: 9.9474e-06
# Incompressible: Iters: 2, residual: 4.1350e-07, Divergence-Free: Iters: 8, residual: 9.9680e-06
# Incompressible: Iters: 2, residual: 4.1355e-07, Divergence-Free: Iters: 9, residual: 9.9375e-06
# Incompressible: Iters: 2, residual: 4.1360e-07, Divergence-Free: Iters: 7, residual: 9.9988e-06
# Incompressible: Iters: 2, residual: 4.1363e-07, Divergence-Free: Iters: 9, residual: 9.9993e-06
# Incompressible: Iters: 2, residual: 4.1366e-07, Divergence-Free: Iters: 9, residual: 9.9347e-06
# Incompressible: Iters: 2, residual: 4.1368e-07, Divergence-Free: Iters: 7, residual: 9.9534e-06
# Incompressible: Iters: 2, residual: 4.1370e-07, Divergence-Free: Iters: 8, residual: 9.9635e-06
# Incompressible: Iters: 2, residual: 4.1370e-07, Divergence-Free: Iters: 8, residual: 9.9828e-06
# Incompressible: Iters: 2, residual: 4.1370e-07, Divergence-Free: Iters: 8, residual: 9.9798e-06
# Incompressible: Iters: 2, residual: 4.1368e-07, Divergence-Free: Iters: 8, residual: 9.9609e-06
# Incompressible: Iters: 2, residual: 4.1365e-07, Divergence-Free: Iters: 8, residual: 9.9337e-06
# Incompressible: Iters: 2, residual: 4.1361e-07, Divergence-Free: Iters: 7, residual: 9.9869e-06
# Incompressible: Iters: 2, residual: 4.1356e-07, Divergence-Free: Iters: 9, residual: 9.9367e-06
# Incompressible: Iters: 2, residual: 4.1349e-07, Divergence-Free: Iters: 7, residual: 9.9652e-06
# Incompressible: Iters: 2, residual: 4.1342e-07, Divergence-Free: Iters: 9, residual: 9.9276e-06
# Incompressible: Iters: 2, residual: 4.1333e-07, Divergence-Free: Iters: 8, residual: 9.9301e-06
# Incompressible: Iters: 2, residual: 4.1323e-07, Divergence-Free: Iters: 8, residual: 9.9625e-06
# Incompressible: Iters: 2, residual: 4.1313e-07, Divergence-Free: Iters: 9, residual: 9.9389e-06
# Incompressible: Iters: 2, residual: 4.1301e-07, Divergence-Free: Iters: 8, residual: 9.9516e-06
# Incompressible: Iters: 2, residual: 4.1288e-07, Divergence-Free: Iters: 8, residual: 9.9670e-06
# Incompressible: Iters: 2, residual: 4.1274e-07, Divergence-Free: Iters: 8, residual: 9.9902e-06
# Incompressible: Iters: 2, residual: 4.1259e-07, Divergence-Free: Iters: 9, residual: 9.9255e-06
# Incompressible: Iters: 2, residual: 4.1244e-07, Divergence-Free: Iters: 7, residual: 9.9789e-06
# Incompressible: Iters: 2, residual: 4.1228e-07, Divergence-Free: Iters: 8, residual: 9.9987e-06
# Incompressible: Iters: 2, residual: 4.1211e-07, Divergence-Free: Iters: 8, residual: 9.9929e-06
# Incompressible: Iters: 2, residual: 4.1193e-07, Divergence-Free: Iters: 8, residual: 9.9729e-06
# Incompressible: Iters: 2, residual: 4.1175e-07, Divergence-Free: Iters: 8, residual: 9.9641e-06
# Incompressible: Iters: 2, residual: 4.1156e-07, Divergence-Free: Iters: 8, residual: 9.9841e-06
# Incompressible: Iters: 2, residual: 4.1137e-07, Divergence-Free: Iters: 9, residual: 9.9276e-06
# Incompressible: Iters: 2, residual: 4.1117e-07, Divergence-Free: Iters: 7, residual: 9.9962e-06
# Incompressible: Iters: 2, residual: 4.1098e-07, Divergence-Free: Iters: 9, residual: 9.9862e-06
# Incompressible: Iters: 2, residual: 4.1079e-07, Divergence-Free: Iters: 8, residual: 9.9901e-06
# Incompressible: Iters: 2, residual: 4.1059e-07, Divergence-Free: Iters: 8, residual: 9.9871e-06
# Incompressible: Iters: 2, residual: 4.1040e-07, Divergence-Free: Iters: 8, residual: 9.9921e-06
# Incompressible: Iters: 2, residual: 4.1021e-07, Divergence-Free: Iters: 9, residual: 9.9541e-06
# Incompressible: Iters: 2, residual: 4.1003e-07, Divergence-Free: Iters: 8, residual: 9.9644e-06
# Incompressible: Iters: 2, residual: 4.0985e-07, Divergence-Free: Iters: 9, residual: 9.9342e-06
# Incompressible: Iters: 2, residual: 4.0969e-07, Divergence-Free: Iters: 8, residual: 9.9645e-06
# Incompressible: Iters: 2, residual: 4.0952e-07, Divergence-Free: Iters: 9, residual: 9.9706e-06
# Incompressible: Iters: 2, residual: 4.0937e-07, Divergence-Free: Iters: 9, residual: 9.9416e-06
# Incompressible: Iters: 2, residual: 4.0924e-07, Divergence-Free: Iters: 8, residual: 9.9875e-06
# Incompressible: Iters: 2, residual: 4.0911e-07, Divergence-Free: Iters: 9, residual: 9.9949e-06
# Incompressible: Iters: 2, residual: 4.0900e-07, Divergence-Free: Iters: 9, residual: 9.9558e-06
# Incompressible: Iters: 2, residual: 4.0890e-07, Divergence-Free: Iters: 8, residual: 9.9745e-06
# Incompressible: Iters: 2, residual: 4.0881e-07, Divergence-Free: Iters: 9, residual: 9.9383e-06
# Incompressible: Iters: 2, residual: 4.0872e-07, Divergence-Free: Iters: 8, residual: 9.9322e-06
# Incompressible: Iters: 2, residual: 4.0863e-07, Divergence-Free: Iters: 8, residual: 9.9441e-06
# Incompressible: Iters: 2, residual: 4.0855e-07, Divergence-Free: Iters: 8, residual: 9.9771e-06
# Incompressible: Iters: 2, residual: 4.0847e-07, Divergence-Free: Iters: 9, residual: 9.9275e-06
# Incompressible: Iters: 2, residual: 4.0839e-07, Divergence-Free: Iters: 7, residual: 9.9676e-06
# Incompressible: Iters: 2, residual: 4.0831e-07, Divergence-Free: Iters: 8, residual: 9.9972e-06
# Incompressible: Iters: 2, residual: 4.0823e-07, Divergence-Free: Iters: 8, residual: 9.9981e-06
# Incompressible: Iters: 2, residual: 4.0815e-07, Divergence-Free: Iters: 8, residual: 9.9731e-06
# Incompressible: Iters: 2, residual: 4.0808e-07, Divergence-Free: Iters: 8, residual: 9.9557e-06
# Incompressible: Iters: 2, residual: 4.0801e-07, Divergence-Free: Iters: 7, residual: 9.9839e-06
# Incompressible: Iters: 2, residual: 4.0794e-07, Divergence-Free: Iters: 9, residual: 9.9374e-06
# Incompressible: Iters: 2, residual: 4.0789e-07, Divergence-Free: Iters: 7, residual: 9.9907e-06
# Incompressible: Iters: 2, residual: 4.0783e-07, Divergence-Free: Iters: 9, residual: 9.9718e-06
# Incompressible: Iters: 2, residual: 4.0777e-07, Divergence-Free: Iters: 8, residual: 9.9818e-06
# Incompressible: Iters: 2, residual: 4.0772e-07, Divergence-Free: Iters: 9, residual: 9.9293e-06
# Incompressible: Iters: 2, residual: 4.0767e-07, Divergence-Free: Iters: 8, residual: 9.9377e-06
# Incompressible: Iters: 2, residual: 4.0763e-07, Divergence-Free: Iters: 8, residual: 9.9709e-06
# Incompressible: Iters: 2, residual: 4.0759e-07, Divergence-Free: Iters: 9, residual: 9.9462e-06
# Incompressible: Iters: 2, residual: 4.0755e-07, Divergence-Free: Iters: 8, residual: 9.9576e-06
# Incompressible: Iters: 2, residual: 4.0752e-07, Divergence-Free: Iters: 9, residual: 9.9250e-06
# Incompressible: Iters: 2, residual: 4.0749e-07, Divergence-Free: Iters: 8, residual: 9.9346e-06
# Incompressible: Iters: 2, residual: 4.0745e-07, Divergence-Free: Iters: 8, residual: 9.9653e-06
# Incompressible: Iters: 2, residual: 4.0742e-07, Divergence-Free: Iters: 9, residual: 9.9405e-06
# Incompressible: Iters: 2, residual: 4.0739e-07, Divergence-Free: Iters: 8, residual: 9.9405e-06
# Incompressible: Iters: 2, residual: 4.0736e-07, Divergence-Free: Iters: 8, residual: 9.9569e-06
# ...
# Incompressible: Iters: 2, residual: 3.8338e-07, Divergence-Free: Iters: 6, residual: 9.9981e-06
# Incompressible: Iters: 2, residual: 3.8343e-07, Divergence-Free: Iters: 9, residual: 9.9239e-06
# Incompressible: Iters: 2, residual: 3.8349e-07, Divergence-Free: Iters: 6, residual: 9.9826e-06
# Incompressible: Iters: 2, residual: 3.8354e-07, Divergence-Free: Iters: 8, residual: 9.9895e-06
# Incompressible: Iters: 2, residual: 3.8360e-07, Divergence-Free: Iters: 8, residual: 9.9273e-06
# Incompressible: Iters: 2, residual: 3.8365e-07, Divergence-Free: Iters: 7, residual: 9.9443e-06
# Incompressible: Iters: 2, residual: 3.8371e-07, Divergence-Free: Iters: 8, residual: 9.9653e-06
# Incompressible: Iters: 2, residual: 3.8376e-07, Divergence-Free: Iters: 8, residual: 9.9782e-06
# Incompressible: Iters: 2, residual: 3.8381e-07, Divergence-Free: Iters: 8, residual: 9.9669e-06
# Incompressible: Iters: 2, residual: 3.8387e-07, Divergence-Free: Iters: 8, residual: 9.9578e-06
# Incompressible: Iters: 2, residual: 3.8392e-07, Divergence-Free: Iters: 8, residual: 9.9569e-06
# Incompressible: Iters: 2, residual: 3.8397e-07, Divergence-Free: Iters: 8, residual: 9.9618e-06
# Incompressible: Iters: 2, residual: 3.8402e-07, Divergence-Free: Iters: 8, residual: 9.9779e-06
# Incompressible: Iters: 2, residual: 3.8406e-07, Divergence-Free: Iters: 8, residual: 9.9645e-06
# Incompressible: Iters: 2, residual: 3.8410e-07, Divergence-Free: Iters: 8, residual: 9.9242e-06
# Incompressible: Iters: 2, residual: 3.8414e-07, Divergence-Free: Iters: 7, residual: 9.9582e-06
# Incompressible: Iters: 2, residual: 3.8416e-07, Divergence-Free: Iters: 8, residual: 9.9445e-06
# Incompressible: Iters: 2, residual: 3.8417e-07, Divergence-Free: Iters: 7, residual: 9.9215e-06
# Incompressible: Iters: 2, residual: 3.8418e-07, Divergence-Free: Iters: 6, residual: 9.9975e-06
# Incompressible: Iters: 2, residual: 3.8416e-07, Divergence-Free: Iters: 8, residual: 9.9842e-06
# Incompressible: Iters: 2, residual: 3.8414e-07, Divergence-Free: Iters: 7, residual: 9.9628e-06
# Incompressible: Iters: 2, residual: 3.8409e-07, Divergence-Free: Iters: 7, residual: 9.9706e-06
# Incompressible: Iters: 2, residual: 3.8404e-07, Divergence-Free: Iters: 8, residual: 9.9220e-06
# Incompressible: Iters: 2, residual: 3.8397e-07, Divergence-Free: Iters: 7, residual: 9.9337e-06
# Incompressible: Iters: 2, residual: 3.8388e-07, Divergence-Free: Iters: 8, residual: 9.9399e-06
# Incompressible: Iters: 2, residual: 3.8378e-07, Divergence-Free: Iters: 8, residual: 9.9334e-06
# Incompressible: Iters: 2, residual: 3.8367e-07, Divergence-Free: Iters: 7, residual: 9.9986e-06
# Incompressible: Iters: 2, residual: 3.8355e-07, Divergence-Free: Iters: 9, residual: 9.9809e-06
# Incompressible: Iters: 2, residual: 3.8343e-07, Divergence-Free: Iters: 8, residual: 9.9606e-06
# Incompressible: Iters: 2, residual: 3.8330e-07, Divergence-Free: Iters: 8, residual: 9.9689e-06
# Incompressible: Iters: 2, residual: 3.8318e-07, Divergence-Free: Iters: 9, residual: 9.9251e-06
# Incompressible: Iters: 2, residual: 3.8305e-07, Divergence-Free: Iters: 7, residual: 9.9773e-06
# Incompressible: Iters: 2, residual: 3.8293e-07, Divergence-Free: Iters: 9, residual: 9.9627e-06
# Incompressible: Iters: 2, residual: 3.8282e-07, Divergence-Free: Iters: 8, residual: 9.9743e-06
# Incompressible: Iters: 2, residual: 3.8272e-07, Divergence-Free: Iters: 8, residual: 9.9737e-06
# Incompressible: Iters: 2, residual: 3.8263e-07, Divergence-Free: Iters: 8, residual: 9.9392e-06
# Incompressible: Iters: 2, residual: 3.8254e-07, Divergence-Free: Iters: 7, residual: 9.9547e-06
# Incompressible: Iters: 2, residual: 3.8247e-07, Divergence-Free: Iters: 8, residual: 9.9224e-06
# Incompressible: Iters: 2, residual: 3.8240e-07, Divergence-Free: Iters: 6, residual: 9.9947e-06
# Incompressible: Iters: 2, residual: 3.8234e-07, Divergence-Free: Iters: 8, residual: 9.9406e-06
# Incompressible: Iters: 2, residual: 3.8228e-07, Divergence-Free: Iters: 6, residual: 9.9629e-06
# Incompressible: Iters: 2, residual: 3.8222e-07, Divergence-Free: Iters: 7, residual: 9.9695e-06
# Incompressible: Iters: 2, residual: 3.8215e-07, Divergence-Free: Iters: 7, residual: 9.9683e-06
# Incompressible: Iters: 2, residual: 3.8209e-07, Divergence-Free: Iters: 7, residual: 9.9780e-06
# Incompressible: Iters: 2, residual: 3.8201e-07, Divergence-Free: Iters: 8, residual: 9.9436e-06
# Incompressible: Iters: 2, residual: 3.8192e-07, Divergence-Free: Iters: 7, residual: 9.9700e-06
# Incompressible: Iters: 2, residual: 3.8183e-07, Divergence-Free: Iters: 9, residual: 9.9363e-06
# Incompressible: Iters: 2, residual: 3.8173e-07, Divergence-Free: Iters: 8, residual: 9.9311e-06
# Incompressible: Iters: 2, residual: 3.8162e-07, Divergence-Free: Iters: 8, residual: 9.9297e-06
# Incompressible: Iters: 2, residual: 3.8150e-07, Divergence-Free: Iters: 8, residual: 9.9308e-06
# Incompressible: Iters: 2, residual: 3.8139e-07, Divergence-Free: Iters: 8, residual: 9.9509e-06
# Incompressible: Iters: 2, residual: 3.8128e-07, Divergence-Free: Iters: 8, residual: 9.9988e-06
# Incompressible: Iters: 2, residual: 3.8116e-07, Divergence-Free: Iters: 9, residual: 9.9615e-06
# Incompressible: Iters: 2, residual: 3.8106e-07, Divergence-Free: Iters: 7, residual: 9.9916e-06
# Incompressible: Iters: 2, residual: 3.8096e-07, Divergence-Free: Iters: 9, residual: 9.9220e-06
# Incompressible: Iters: 2, residual: 3.8087e-07, Divergence-Free: Iters: 7, residual: 9.9198e-06
# Incompressible: Iters: 2, residual: 3.8080e-07, Divergence-Free: Iters: 7, residual: 9.9641e-06
# Incompressible: Iters: 2, residual: 3.8073e-07, Divergence-Free: Iters: 8, residual: 9.9400e-06
# Incompressible: Iters: 2, residual: 3.8066e-07, Divergence-Free: Iters: 7, residual: 9.9509e-06
# Incompressible: Iters: 2, residual: 3.8062e-07, Divergence-Free: Iters: 8, residual: 9.9291e-06
# Incompressible: Iters: 2, residual: 3.8057e-07, Divergence-Free: Iters: 7, residual: 9.9474e-06
# Incompressible: Iters: 2, residual: 3.8055e-07, Divergence-Free: Iters: 7, residual: 9.9941e-06
# Incompressible: Iters: 2, residual: 3.8052e-07, Divergence-Free: Iters: 8, residual: 9.9983e-06
# Incompressible: Iters: 2, residual: 3.8051e-07, Divergence-Free: Iters: 8, residual: 9.9823e-06
# Incompressible: Iters: 2, residual: 3.8050e-07, Divergence-Free: Iters: 8, residual: 9.9601e-06
# Incompressible: Iters: 2, residual: 3.8051e-07, Divergence-Free: Iters: 8, residual: 9.9642e-06
# Incompressible: Iters: 2, residual: 3.8052e-07, Divergence-Free: Iters: 8, residual: 9.9721e-06
# Incompressible: Iters: 2, residual: 3.8054e-07, Divergence-Free: Iters: 8, residual: 9.9819e-06
# Incompressible: Iters: 2, residual: 3.8057e-07, Divergence-Free: Iters: 8, residual: 9.9706e-06
# Incompressible: Iters: 2, residual: 3.8062e-07, Divergence-Free: Iters: 8, residual: 9.9540e-06
# Incompressible: Iters: 2, residual: 3.8066e-07, Divergence-Free: Iters: 8, residual: 9.9333e-06
# Incompressible: Iters: 2, residual: 3.8072e-07, Divergence-Free: Iters: 7, residual: 9.9844e-06
# Incompressible: Iters: 2, residual: 3.8077e-07, Divergence-Free: Iters: 8, residual: 9.9556e-06
# Incompressible: Iters: 2, residual: 3.8083e-07, Divergence-Free: Iters: 7, residual: 9.9570e-06
# Incompressible: Iters: 2, residual: 3.8089e-07, Divergence-Free: Iters: 8, residual: 9.9352e-06
# Incompressible: Iters: 2, residual: 3.8095e-07, Divergence-Free: Iters: 7, residual: 9.9821e-06
# Incompressible: Iters: 2, residual: 3.8101e-07, Divergence-Free: Iters: 9, residual: 9.9299e-06
# Incompressible: Iters: 2, residual: 3.8108e-07, Divergence-Free: Iters: 7, residual: 9.9626e-06
# Incompressible: Iters: 2, residual: 3.8115e-07, Divergence-Free: Iters: 9, residual: 9.9509e-06
# Incompressible: Iters: 2, residual: 3.8122e-07, Divergence-Free: Iters: 8, residual: 9.9445e-06
# Incompressible: Iters: 2, residual: 3.8129e-07, Divergence-Free: Iters: 8, residual: 9.9418e-06
# Incompressible: Iters: 2, residual: 3.8137e-07, Divergence-Free: Iters: 8, residual: 9.9425e-06
# Incompressible: Iters: 2, residual: 3.8144e-07, Divergence-Free: Iters: 8, residual: 9.9396e-06
# Incompressible: Iters: 2, residual: 3.8152e-07, Divergence-Free: Iters: 7, residual: 9.9740e-06
# Incompressible: Iters: 2, residual: 3.8159e-07, Divergence-Free: Iters: 7, residual: 9.9940e-06
# Incompressible: Iters: 2, residual: 3.8166e-07, Divergence-Free: Iters: 8, residual: 9.9348e-06
# Incompressible: Iters: 2, residual: 3.8172e-07, Divergence-Free: Iters: 7, residual: 9.9233e-06
# Incompressible: Iters: 2, residual: 3.8178e-07, Divergence-Free: Iters: 7, residual: 9.9476e-06
# Incompressible: Iters: 2, residual: 3.8184e-07, Divergence-Free: Iters: 8, residual: 9.9273e-06
# Incompressible: Iters: 2, residual: 3.8189e-07, Divergence-Free: Iters: 7, residual: 9.9517e-06
# Incompressible: Iters: 2, residual: 3.8194e-07, Divergence-Free: Iters: 8, residual: 9.9368e-06
# Incompressible: Iters: 2, residual: 3.8199e-07, Divergence-Free: Iters: 7, residual: 9.9879e-06
# Incompressible: Iters: 2, residual: 3.8203e-07, Divergence-Free: Iters: 9, residual: 9.9623e-06
# Incompressible: Iters: 2, residual: 3.8207e-07, Divergence-Free: Iters: 8, residual: 9.9496e-06
# Incompressible: Iters: 2, residual: 3.8211e-07, Divergence-Free: Iters: 8, residual: 9.9272e-06
# Incompressible: Iters: 2, residual: 3.8213e-07, Divergence-Free: Iters: 7, residual: 9.9912e-06
# Incompressible: Iters: 2, residual: 3.8217e-07, Divergence-Free: Iters: 9, residual: 9.9634e-06
# Incompressible: Iters: 2, residual: 3.8219e-07, Divergence-Free: Iters: 8, residual: 9.9306e-06
# Incompressible: Iters: 2, residual: 3.8221e-07, Divergence-Free: Iters: 7, residual: 9.9662e-06
# Incompressible: Iters: 2, residual: 3.8223e-07, Divergence-Free: Iters: 8, residual: 9.9604e-06
# Incompressible: Iters: 2, residual: 3.8224e-07, Divergence-Free: Iters: 7, residual: 9.9791e-06
# Incompressible: Iters: 2, residual: 3.8225e-07, Divergence-Free: Iters: 8, residual: 9.9255e-06
# Incompressible: Iters: 2, residual: 3.8226e-07, Divergence-Free: Iters: 6, residual: 9.9965e-06
# Incompressible: Iters: 2, residual: 3.8228e-07, Divergence-Free: Iters: 8, residual: 9.9985e-06
# Incompressible: Iters: 2, residual: 3.8230e-07, Divergence-Free: Iters: 8, residual: 9.9345e-06
# Incompressible: Iters: 2, residual: 3.8232e-07, Divergence-Free: Iters: 7, residual: 9.9216e-06
# Incompressible: Iters: 2, residual: 3.8236e-07, Divergence-Free: Iters: 7, residual: 9.9689e-06
# Incompressible: Iters: 2, residual: 3.8240e-07, Divergence-Free: Iters: 8, residual: 9.9996e-06
# Incompressible: Iters: 2, residual: 3.8245e-07, Divergence-Free: Iters: 8, residual: 9.9996e-06
# Incompressible: Iters: 2, residual: 3.8250e-07, Divergence-Free: Iters: 9, residual: 9.9220e-06
# Incompressible: Iters: 2, residual: 3.8257e-07, Divergence-Free: Iters: 7, residual: 9.9581e-06
# Incompressible: Iters: 2, residual: 3.8263e-07, Divergence-Free: Iters: 8, residual: 9.9976e-06
# Incompressible: Iters: 2, residual: 3.8270e-07, Divergence-Free: Iters: 9, residual: 9.9301e-06
# Incompressible: Iters: 2, residual: 3.8276e-07, Divergence-Free: Iters: 7, residual: 9.9511e-06
# Incompressible: Iters: 2, residual: 3.8282e-07, Divergence-Free: Iters: 8, residual: 9.9684e-06
# Incompressible: Iters: 2, residual: 3.8287e-07, Divergence-Free: Iters: 8, residual: 9.9566e-06
# Incompressible: Iters: 2, residual: 3.8292e-07, Divergence-Free: Iters: 7, residual: 9.9710e-06
# Incompressible: Iters: 2, residual: 3.8296e-07, Divergence-Free: Iters: 8, residual: 9.9285e-06
# Incompressible: Iters: 2, residual: 3.8299e-07, Divergence-Free: Iters: 7, residual: 9.9355e-06
# Incompressible: Iters: 2, residual: 3.8301e-07, Divergence-Free: Iters: 7, residual: 9.9821e-06
# Incompressible: Iters: 2, residual: 3.8302e-07, Divergence-Free: Iters: 8, residual: 9.9723e-06
# Incompressible: Iters: 2, residual: 3.8303e-07, Divergence-Free: Iters: 8, residual: 9.9369e-06
# Incompressible: Iters: 2, residual: 3.8303e-07, Divergence-Free: Iters: 7, residual: 9.9633e-06
# Incompressible: Iters: 2, residual: 3.8303e-07, Divergence-Free: Iters: 8, residual: 9.9657e-06
# Incompressible: Iters: 2, residual: 3.8302e-07, Divergence-Free: Iters: 8, residual: 9.9471e-06
# Incompressible: Iters: 2, residual: 3.8300e-07, Divergence-Free: Iters: 7, residual: 9.9828e-06
# Incompressible: Iters: 2, residual: 3.8299e-07, Divergence-Free: Iters: 8, residual: 9.9761e-06
# Incompressible: Iters: 2, residual: 3.8297e-07, Divergence-Free: Iters: 8, residual: 9.9484e-06
# Incompressible: Iters: 2, residual: 3.8294e-07, Divergence-Free: Iters: 8, residual: 9.9210e-06
# Incompressible: Iters: 2, residual: 3.8292e-07, Divergence-Free: Iters: 7, residual: 9.9637e-06
# Incompressible: Iters: 2, residual: 3.8289e-07, Divergence-Free: Iters: 8, residual: 9.9550e-06
# Incompressible: Iters: 2, residual: 3.8286e-07, Divergence-Free: Iters: 7, residual: 9.9956e-06
# Incompressible: Iters: 2, residual: 3.8283e-07, Divergence-Free: Iters: 9, residual: 9.9234e-06
# Incompressible: Iters: 2, residual: 3.8280e-07, Divergence-Free: Iters: 7, residual: 9.9487e-06
# Incompressible: Iters: 2, residual: 3.8277e-07, Divergence-Free: Iters: 7, residual: 9.9908e-06
# Incompressible: Iters: 2, residual: 3.8274e-07, Divergence-Free: Iters: 8, residual: 9.9620e-06
# Incompressible: Iters: 2, residual: 3.8271e-07, Divergence-Free: Iters: 7, residual: 9.9769e-06
# Incompressible: Iters: 2, residual: 3.8269e-07, Divergence-Free: Iters: 8, residual: 9.9607e-06
# Incompressible: Iters: 2, residual: 3.8268e-07, Divergence-Free: Iters: 8, residual: 9.9305e-06
# Incompressible: Iters: 2, residual: 3.8266e-07, Divergence-Free: Iters: 7, residual: 9.9721e-06
# Incompressible: Iters: 2, residual: 3.8266e-07, Divergence-Free: Iters: 8, residual: 9.9931e-06
# Incompressible: Iters: 2, residual: 3.8266e-07, Divergence-Free: Iters: 8, residual: 9.9918e-06
# Incompressible: Iters: 2, residual: 3.8266e-07, Divergence-Free: Iters: 8, residual: 9.9939e-06
# Incompressible: Iters: 2, residual: 3.8267e-07, Divergence-Free: Iters: 9, residual: 9.9250e-06
# Incompressible: Iters: 2, residual: 3.8269e-07, Divergence-Free: Iters: 7, residual: 9.9581e-06
# Incompressible: Iters: 2, residual: 3.8271e-07, Divergence-Free: Iters: 8, residual: 9.9516e-06
# Incompressible: Iters: 2, residual: 3.8273e-07, Divergence-Free: Iters: 8, residual: 9.9531e-06
# Incompressible: Iters: 2, residual: 3.8275e-07, Divergence-Free: Iters: 8, residual: 9.9388e-06
# Incompressible: Iters: 2, residual: 3.8277e-07, Divergence-Free: Iters: 7, residual: 9.9923e-06
# Incompressible: Iters: 2, residual: 3.8279e-07, Divergence-Free: Iters: 8, residual: 9.9694e-06
# Incompressible: Iters: 2, residual: 3.8281e-07, Divergence-Free: Iters: 7, residual: 9.9520e-06
# Incompressible: Iters: 2, residual: 3.8283e-07, Divergence-Free: Iters: 7, residual: 9.9538e-06
# Incompressible: Iters: 2, residual: 3.8284e-07, Divergence-Free: Iters: 7, residual: 9.9675e-06
# Incompressible: Iters: 2, residual: 3.8286e-07, Divergence-Free: Iters: 8, residual: 9.9248e-06
# Incompressible: Iters: 2, residual: 3.8287e-07, Divergence-Free: Iters: 6, residual: 9.9951e-06
# Incompressible: Iters: 2, residual: 3.8289e-07, Divergence-Free: Iters: 8, residual: 9.9999e-06
# Incompressible: Iters: 2, residual: 3.8290e-07, Divergence-Free: Iters: 8, residual: 9.9617e-06
# Incompressible: Iters: 2, residual: 3.8292e-07, Divergence-Free: Iters: 8, residual: 9.9251e-06
# Incompressible: Iters: 2, residual: 3.8294e-07, Divergence-Free: Iters: 7, residual: 9.9643e-06
# Incompressible: Iters: 2, residual: 3.8296e-07, Divergence-Free: Iters: 8, residual: 9.9721e-06
# Incompressible: Iters: 2, residual: 3.8299e-07, Divergence-Free: Iters: 8, residual: 9.9598e-06
# Incompressible: Iters: 2, residual: 3.8302e-07, Divergence-Free: Iters: 8, residual: 9.9411e-06
# Incompressible: Iters: 2, residual: 3.8306e-07, Divergence-Free: Iters: 7, residual: 9.9853e-06
# Incompressible: Iters: 2, residual: 3.8310e-07, Divergence-Free: Iters: 8, residual: 9.9891e-06
# Incompressible: Iters: 2, residual: 3.8315e-07, Divergence-Free: Iters: 8, residual: 9.9720e-06
# Incompressible: Iters: 2, residual: 3.8320e-07, Divergence-Free: Iters: 8, residual: 9.9213e-06

# %%
import subprocess
import shlex

outFile = config['plot']['namingScheme'] if config['plot']['namingScheme'] != 'timestep' else config["simulation"]["timestamp"]
if config['plot']['namingScheme'] == 'timestep':
    outFolder = f'{config["plot"]["exportPath"]}/{config["simulation"]["timestamp"]}/'
else:
    outFolder = f'{config["plot"]["exportPath"]}/{config["plot"]["namingScheme"]}/'

os.makedirs(outFolder, exist_ok = True)
# print('Creating video from  frames (frame count: {})'.format(len(os.listdir(outFolder))))
command = '/usr/bin/ffmpeg -loglevel warning -y -framerate 30 -f image2 -pattern_type glob -i '+ outFolder + '*.png -c:v libx264 -b:v 20M -r ' + str(config['plot']['exportFPS']) + ' ' + outFolder + 'output.mp4'
commandB = f'ffmpeg -loglevel warning -hide_banner -y -i {outFolder}output.mp4 -vf "fps={config["plot"]["exportFPS"]},scale={config["plot"]["gifScale"]}:-1:flags=lanczos,palettegen" output/palette.png'
commandC = f'ffmpeg -loglevel warning -hide_banner -y -i {outFolder}output.mp4 -i output/palette.png -filter_complex "fps={config["plot"]["exportFPS"]},scale={config["plot"]["gifScale"]}:-1:flags=lanczos[x];[x][1:v]paletteuse" {outFile}.gif'

subprocess.run(shlex.split(command))
subprocess.run(shlex.split(commandB))
subprocess.run(shlex.split(commandC))
# Out:
# CompletedProcess(args=['ffmpeg', '-loglevel', 'warning', '-hide_banner', '-y', '-i', 'output/2024_07_04-14_08_25/output.mp4', '-i', 'output/palette.png', '-filter_complex', 'fps=30,scale=640:-1:flags=lanczos[x];[x][1:v]paletteuse', '2024_07_04-14_08_25.gif'], returncode=0)
